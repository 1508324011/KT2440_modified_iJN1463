# %%
import cobra
from cobra import Reaction, Metabolite
from cobra.io import read_sbml_model
from cobra.flux_analysis import production_envelope
import networkx as nx
import matplotlib.pyplot as plt
model  = read_sbml_model('iJN1463.xml')

# %%
model
# Out:
# <Model iJN1463 at 0x1b4eef2fe30>

# %%
for reaction in model.reactions:
    reaction.upper_bound = 1000

# %%
for reaction in model.reactions:
    print(f"反应: {reaction.id}, 下限: {reaction.lower_bound}, 上限: {reaction.upper_bound}")
# Out:
# 反应: 3HAD160, 下限: 0.0, 上限: 1000
# 反应: 13DAMPPabcpp, 下限: 0.0, 上限: 1000
# 反应: 13DAMPPtex, 下限: -999999.0, 上限: 1000
# 反应: 15DAPabcpp, 下限: 0.0, 上限: 1000
# 反应: 1P2CBXLCYCL, 下限: -999999.0, 上限: 1000
# 反应: 1P2CBXLR, 下限: 0.0, 上限: 1000
# 反应: 1PPDCRc, 下限: 0.0, 上限: 1000
# 反应: 1PQQS, 下限: -999999.0, 上限: 1000
# 反应: 1PY4h3cAH, 下限: 0.0, 上限: 1000
# 反应: 23CTI1, 下限: 0.0, 上限: 1000
# 反应: 23CTI2, 下限: 0.0, 上限: 1000
# 反应: 23CTI3, 下限: 0.0, 上限: 1000
# 反应: 24DECOAR, 下限: 0.0, 上限: 1000
# 反应: 25DKGLCNt2rpp, 下限: -999999.0, 上限: 1000
# 反应: 25DKGLCNtex, 下限: -999999.0, 上限: 1000
# 反应: 26DAHtex, 下限: -999999.0, 上限: 1000
# 反应: 2AACLPGT160, 下限: 0.0, 上限: 1000
# 反应: 2AACLPGT161, 下限: 0.0, 上限: 1000
# 反应: 2AACLPGT180, 下限: 0.0, 上限: 1000
# 反应: 2AACLPGT181, 下限: 0.0, 上限: 1000
# 反应: 2AACLPPEAT160, 下限: 0.0, 上限: 1000
# 反应: 2AACLPPEAT161, 下限: 0.0, 上限: 1000
# 反应: 2AACLPPEAT180, 下限: 0.0, 上限: 1000
# 反应: 2AACLPPEAT181, 下限: 0.0, 上限: 1000
# 反应: 2AGPE160tipp, 下限: 0.0, 上限: 1000
# 反应: 2AGPE161tipp, 下限: 0.0, 上限: 1000
# 反应: 2AGPE180tipp, 下限: 0.0, 上限: 1000
# 反应: 2AGPE181tipp, 下限: 0.0, 上限: 1000
# 反应: 2AGPG160tipp, 下限: 0.0, 上限: 1000
# 反应: 2AGPG161tipp, 下限: 0.0, 上限: 1000
# 反应: 2AGPG180tipp, 下限: 0.0, 上限: 1000
# 反应: 2AGPG181tipp, 下限: 0.0, 上限: 1000
# 反应: 2DHGLCK, 下限: 0.0, 上限: 1000
# 反应: 2DHGLCNkt_tpp, 下限: 0.0, 上限: 1000
# 反应: 2DHGLCNtex, 下限: -999999.0, 上限: 1000
# 反应: 2PQQS, 下限: -999999.0, 上限: 1000
# 反应: 34DHCINMtex, 下限: -999999.0, 上限: 1000
# 反应: 34DHCINMtpp, 下限: -999999.0, 上限: 1000
# 反应: 34DHPHEtex, 下限: -999999.0, 上限: 1000
# 反应: 34DHPHEtpp, 下限: 0.0, 上限: 1000
# 反应: 34HPPOR, 下限: 0.0, 上限: 1000
# 反应: 3AIBT2, 下限: -999999.0, 上限: 1000
# 反应: 3HAACOAT100, 下限: -999999.0, 上限: 1000
# 反应: 3HAACOAT120, 下限: -999999.0, 上限: 1000
# 反应: 3HAACOAT121, 下限: -999999.0, 上限: 1000
# 反应: 3HAACOAT140, 下限: -999999.0, 上限: 1000
# 反应: 3HAACOAT141, 下限: -999999.0, 上限: 1000
# 反应: 3HAACOAT60, 下限: -999999.0, 上限: 1000
# 反应: 3HAACOAT80, 下限: -999999.0, 上限: 1000
# 反应: 3HAD100, 下限: 0.0, 上限: 1000
# 反应: 3HAD120, 下限: 0.0, 上限: 1000
# 反应: 3HAD121, 下限: 0.0, 上限: 1000
# 反应: 3HAD140, 下限: 0.0, 上限: 1000
# 反应: 3HAD141, 下限: 0.0, 上限: 1000
# 反应: ACOAD31f, 下限: -999999.0, 上限: 1000
# 反应: ACOAD32f, 下限: -999999.0, 上限: 1000
# 反应: ACOAD33f, 下限: -999999.0, 上限: 1000
# 反应: ACOAD34f, 下限: -999999.0, 上限: 1000
# 反应: ACOAD3f, 下限: -999999.0, 上限: 1000
# 反应: ACOAD4f, 下限: -999999.0, 上限: 1000
# 反应: ACOAD5f, 下限: -999999.0, 上限: 1000
# 反应: ACOAD6f, 下限: -999999.0, 上限: 1000
# 反应: ACOAD7f, 下限: -999999.0, 上限: 1000
# 反应: ACOAD8f, 下限: -999999.0, 上限: 1000
# 反应: ACOADH1, 下限: 0.0, 上限: 1000
# 反应: ACOADH2, 下限: 0.0, 上限: 1000
# 反应: ACOATA, 下限: -999999.0, 上限: 1000
# 反应: ACODA, 下限: 0.0, 上限: 1000
# 反应: ACONCt4pp, 下限: 0.0, 上限: 1000
# 反应: ACONCtex, 下限: -999999.0, 上限: 1000
# 反应: ACONIs, 下限: -999999.0, 上限: 1000
# 反应: ACONMT, 下限: 0.0, 上限: 1000
# 反应: ACONTa, 下限: -999999.0, 上限: 1000
# 反应: ACONTb, 下限: -999999.0, 上限: 1000
# 反应: ACOTA, 下限: -999999.0, 上限: 1000
# 反应: ACPPAT120, 下限: 0.0, 上限: 1000
# 反应: ACPPAT140, 下限: 0.0, 上限: 1000
# 反应: ACPPAT141, 下限: 0.0, 上限: 1000
# 反应: ACPPAT160, 下限: 0.0, 上限: 1000
# 反应: ACPPAT161, 下限: 0.0, 上限: 1000
# 反应: ACPPAT180, 下限: 0.0, 上限: 1000
# 反应: ACPPAT181, 下限: 0.0, 上限: 1000
# 反应: ACPS1, 下限: 0.0, 上限: 1000
# 反应: ACS, 下限: 0.0, 上限: 1000
# 反应: ACS2, 下限: 0.0, 上限: 1000
# 反应: ACSERtex, 下限: -999999.0, 上限: 1000
# 反应: ACSERtpp, 下限: 0.0, 上限: 1000
# 反应: ACSPHAC100, 下限: 0.0, 上限: 1000
# 反应: ACSPHAC101, 下限: 0.0, 上限: 1000
# 反应: ACSPHAC120, 下限: 0.0, 上限: 1000
# 反应: ACSPHAC121, 下限: 0.0, 上限: 1000
# 反应: ACSPHAC121d6, 下限: 0.0, 上限: 1000
# 反应: ACSPHAC140, 下限: 0.0, 上限: 1000
# 反应: ACSPHAC141, 下限: 0.0, 上限: 1000
# 反应: ACSPHAC141d5, 下限: 0.0, 上限: 1000
# 反应: ACSPHAC142, 下限: 0.0, 上限: 1000
# 反应: ACSPHAC160, 下限: 0.0, 上限: 1000
# 反应: ACSPHAC40, 下限: 0.0, 上限: 1000
# 反应: ACSPHAC50, 下限: 0.0, 上限: 1000
# 反应: ACSPHAC60, 下限: 0.0, 上限: 1000
# 反应: ACSPHAC70, 下限: 0.0, 上限: 1000
# 反应: ACSPHAC80, 下限: 0.0, 上限: 1000
# 反应: ACSPHAC90, 下限: 0.0, 上限: 1000
# 反应: ACSPHACP100, 下限: 0.0, 上限: 1000
# 反应: ACSPHACP40, 下限: 0.0, 上限: 1000
# 反应: ACSPHACP50, 下限: 0.0, 上限: 1000
# 反应: ACSPHACP60, 下限: 0.0, 上限: 1000
# 反应: ACSPHACP70, 下限: 0.0, 上限: 1000
# 反应: ACSPHACP80, 下限: 0.0, 上限: 1000
# 反应: ACSPHACP90, 下限: 0.0, 上限: 1000
# 反应: ACSPHACT40, 下限: 0.0, 上限: 1000
# 反应: ACSPHACT60, 下限: 0.0, 上限: 1000
# 反应: DGUDBUTNabcpp, 下限: 0.0, 上限: 1000
# 反应: ALGE9, 下限: -999999.0, 上限: 1000
# 反应: ALGL, 下限: 0.0, 上限: 1000
# 反应: ALGL2, 下限: 0.0, 上限: 1000
# 反应: ALGSex1, 下限: 0.0, 上限: 1000
# 反应: ALGSex10, 下限: 0.0, 上限: 1000
# 反应: ALGSex11, 下限: 0.0, 上限: 1000
# 反应: ALGSex12, 下限: 0.0, 上限: 1000
# 反应: ALGSex13, 下限: 0.0, 上限: 1000
# 反应: ALGSex2, 下限: 0.0, 上限: 1000
# 反应: ALGSex3, 下限: 0.0, 上限: 1000
# 反应: ALGSex4, 下限: 0.0, 上限: 1000
# 反应: ALGSex5, 下限: 0.0, 上限: 1000
# 反应: ALGSex6, 下限: 0.0, 上限: 1000
# 反应: ALGSex7, 下限: 0.0, 上限: 1000
# 反应: ALGSex8, 下限: 0.0, 上限: 1000
# 反应: ALGSex9, 下限: 0.0, 上限: 1000
# 反应: ALLTAMH, 下限: 0.0, 上限: 1000
# 反应: ALLTN, 下限: 0.0, 上限: 1000
# 反应: ALLTNRA, 下限: -999999.0, 上限: 1000
# 反应: ALLTNt2rpp, 下限: -999999.0, 上限: 1000
# 反应: ALLTNtex, 下限: -999999.0, 上限: 1000
# 反应: ALPATE160pp, 下限: 0.0, 上限: 1000
# 反应: ALPATE161pp, 下限: 0.0, 上限: 1000
# 反应: ALPATE180pp, 下限: 0.0, 上限: 1000
# 反应: ALPATE181pp, 下限: 0.0, 上限: 1000
# 反应: ALPATG160pp, 下限: 0.0, 上限: 1000
# 反应: ALPATG161pp, 下限: 0.0, 上限: 1000
# 反应: ALPATG180pp, 下限: 0.0, 上限: 1000
# 反应: ALPATG181pp, 下限: 0.0, 上限: 1000
# 反应: ALTRH, 下限: 0.0, 上限: 1000
# 反应: AM3PA, 下限: 0.0, 上限: 1000
# 反应: AM4PA, 下限: 0.0, 上限: 1000
# 反应: AM4PCP, 下限: 0.0, 上限: 1000
# 反应: AMAOTr, 下限: -999999.0, 上限: 1000
# 反应: AMID4, 下限: 0.0, 上限: 1000
# 反应: AMPMS2, 下限: 0.0, 上限: 1000
# 反应: AMPN, 下限: 0.0, 上限: 1000
# 反应: AMPTASEAH, 下限: 0.0, 上限: 1000
# 反应: AMPTASEAL, 下限: 0.0, 上限: 1000
# 反应: AMPTASEAT, 下限: 0.0, 上限: 1000
# 反应: AMPTASEATRP, 下限: 0.0, 上限: 1000
# 反应: AMPTASECG, 下限: 0.0, 上限: 1000
# 反应: GLYGLYCNc, 下限: 0.0, 上限: 1000
# 反应: AMPTASEGGLN, 下限: 0.0, 上限: 1000
# 反应: AMPTASEGGLU, 下限: 0.0, 上限: 1000
# 反应: AMPTASEGM, 下限: 0.0, 上限: 1000
# 反应: GLYPHEHYc, 下限: 0.0, 上限: 1000
# 反应: AMPTASEGS, 下限: 0.0, 上限: 1000
# 反应: AMPTASEHG, 下限: 0.0, 上限: 1000
# 反应: AMPTASEHH, 下限: 0.0, 上限: 1000
# 反应: LEULEULAPc, 下限: 0.0, 上限: 1000
# 反应: AMPTASEPG, 下限: 0.0, 上限: 1000
# 反应: ANHMK, 下限: 0.0, 上限: 1000
# 反应: ANPRT, 下限: 0.0, 上限: 1000
# 反应: ANS, 下限: 0.0, 上限: 1000
# 反应: ANS2, 下限: 0.0, 上限: 1000
# 反应: AOBUTDs, 下限: 0.0, 上限: 1000
# 反应: AOXHEXCYCL, 下限: -999999.0, 上限: 1000
# 反应: AOXSr2, 下限: 0.0, 上限: 1000
# 反应: AP4AH, 下限: 0.0, 上限: 1000
# 反应: AP4AS, 下限: 0.0, 上限: 1000
# 反应: APATr, 下限: -999999.0, 上限: 1000
# 反应: APCt5, 下限: 0.0, 上限: 1000
# 反应: APCt6, 下限: 0.0, 上限: 1000
# 反应: APCtex, 下限: -999999.0, 上限: 1000
# 反应: APCtpp, 下限: 0.0, 上限: 1000
# 反应: APENTAMAH2, 下限: 0.0, 上限: 1000
# 反应: APG3PAT120, 下限: 0.0, 上限: 1000
# 反应: APG3PAT140, 下限: 0.0, 上限: 1000
# 反应: APG3PAT141, 下限: 0.0, 上限: 1000
# 反应: APG3PAT160, 下限: 0.0, 上限: 1000
# 反应: APG3PAT161, 下限: 0.0, 上限: 1000
# 反应: APG3PAT180, 下限: 0.0, 上限: 1000
# 反应: APG3PAT181, 下限: 0.0, 上限: 1000
# 反应: APPLDHr, 下限: -999999.0, 上限: 1000
# 反应: APRAUR, 下限: 0.0, 上限: 1000
# 反应: APSR, 下限: 0.0, 上限: 1000
# 反应: APSR2, 下限: 0.0, 上限: 1000
# 反应: APTNAT, 下限: -999999.0, 上限: 1000
# 反应: ARBTNR1, 下限: 0.0, 上限: 1000
# 反应: ARBTNR2, 下限: 0.0, 上限: 1000
# 反应: ARBTNabcpp, 下限: 0.0, 上限: 1000
# 反应: ARBTNexs, 下限: 0.0, 上限: 1000
# 反应: ARBTNtex, 下限: 0.0, 上限: 1000
# 反应: ARBTNtonex, 下限: 0.0, 上限: 1000
# 反应: ARBTNtpp, 下限: 0.0, 上限: 1000
# 反应: ARBt3ipp, 下限: 0.0, 上限: 1000
# 反应: ARGDr, 下限: 0.0, 上限: 1000
# 反应: ARGDC, 下限: 0.0, 上限: 1000
# 反应: ARGDCpp, 下限: 0.0, 上限: 1000
# 反应: ARGORNt7pp, 下限: -999999.0, 上限: 1000
# 反应: ARGSL, 下限: -999999.0, 上限: 1000
# 反应: ARGSS, 下限: 0.0, 上限: 1000
# 反应: ARGTRS, 下限: 0.0, 上限: 1000
# 反应: ARGabcpp, 下限: 0.0, 上限: 1000
# 反应: ARGt2pp, 下限: 0.0, 上限: 1000
# 反应: ARGtex, 下限: -999999.0, 上限: 1000
# 反应: AROH, 下限: 0.0, 上限: 1000
# 反应: ARUH, 下限: -999999.0, 上限: 1000
# 反应: ASAD, 下限: -999999.0, 上限: 1000
# 反应: ASNN, 下限: 0.0, 上限: 1000
# 反应: ASNNpp, 下限: 0.0, 上限: 1000
# 反应: ASNS1, 下限: 0.0, 上限: 1000
# 反应: ASNtex, 下限: -999999.0, 上限: 1000
# 反应: ASO3t2pp, 下限: 0.0, 上限: 1000
# 反应: ASO3tex, 下限: -999999.0, 上限: 1000
# 反应: ASO4rt2rpp, 下限: 0.0, 上限: 1000
# 反应: ASO4tex, 下限: -999999.0, 上限: 1000
# 反应: ASP3H, 下限: 0.0, 上限: 1000
# 反应: ASPCT, 下限: 0.0, 上限: 1000
# 反应: ASPK, 下限: -999999.0, 上限: 1000
# 反应: ASPO1, 下限: 0.0, 上限: 1000
# 反应: ASPO3, 下限: 0.0, 上限: 1000
# 反应: ASPO5, 下限: 0.0, 上限: 1000
# 反应: ASPO6, 下限: 0.0, 上限: 1000
# 反应: ASPSALy, 下限: 0.0, 上限: 1000
# 反应: ASPT, 下限: 0.0, 上限: 1000
# 反应: BZDH, 下限: 0.0, 上限: 1000
# 反应: BZDIOLDH, 下限: 0.0, 上限: 1000
# 反应: BZt1pp, 下限: -999999.0, 上限: 1000
# 反应: BZt2_pp, 下限: 0.0, 上限: 1000
# 反应: BZtex, 下限: -999999.0, 上限: 1000
# 反应: BIOMASS_KT2440_Core2, 下限: 0.0, 上限: 1000
# 反应: BIOMASS_KT2440_WT3, 下限: 0.0, 上限: 1000
# 反应: CA2tex, 下限: -999999.0, 上限: 1000
# 反应: CACOAHA, 下限: 0.0, 上限: 1000
# 反应: CAFFCOA, 下限: 0.0, 上限: 1000
# 反应: CARBSARAH, 下限: 0.0, 上限: 1000
# 反应: CARNabcpp, 下限: 0.0, 上限: 1000
# 反应: CARNtex, 下限: -999999.0, 上限: 1000
# 反应: CAT, 下限: 0.0, 上限: 1000
# 反应: CAT23DOX, 下限: 0.0, 上限: 1000
# 反应: CATDOX, 下限: 0.0, 上限: 1000
# 反应: CATECHOLtex, 下限: -999999.0, 上限: 1000
# 反应: CATECHOLtpp, 下限: -999999.0, 上限: 1000
# 反应: CATpp, 下限: 0.0, 上限: 1000
# 反应: CAt6pp, 下限: -999999.0, 上限: 1000
# 反应: CBIAT, 下限: -999999.0, 上限: 1000
# 反应: CBItonex, 下限: 0.0, 上限: 1000
# 反应: CBIuabcpp, 下限: 0.0, 上限: 1000
# 反应: CBL1abcpp, 下限: 0.0, 上限: 1000
# 反应: CBL1tonex, 下限: 0.0, 上限: 1000
# 反应: CBLAT, 下限: -999999.0, 上限: 1000
# 反应: CBMKr, 下限: -999999.0, 上限: 1000
# 反应: CBPAH, 下限: 0.0, 上限: 1000
# 反应: CBPS, 下限: 0.0, 上限: 1000
# 反应: CCGS, 下限: 0.0, 上限: 1000
# 反应: CCPpp, 下限: 0.0, 上限: 1000
# 反应: CD2abcpp, 下限: 0.0, 上限: 1000
# 反应: CD2t3pp, 下限: 0.0, 上限: 1000
# 反应: CD2t4pp, 下限: 0.0, 上限: 1000
# 反应: CD2t5, 下限: 0.0, 上限: 1000
# 反应: CD2t6, 下限: 0.0, 上限: 1000
# 反应: CD2tex, 下限: -999999.0, 上限: 1000
# 反应: CD2tpp, 下限: 0.0, 上限: 1000
# 反应: CDGR, 下限: 0.0, 上限: 1000
# 反应: CDGS, 下限: 0.0, 上限: 1000
# 反应: CDPMEK, 下限: 0.0, 上限: 1000
# 反应: CELASEpp, 下限: 0.0, 上限: 1000
# 反应: CELLS, 下限: 0.0, 上限: 1000
# 反应: CELLex, 下限: 0.0, 上限: 1000
# 反应: CFAS160E, 下限: 0.0, 上限: 1000
# 反应: CFAS160G, 下限: 0.0, 上限: 1000
# 反应: CFAS180E, 下限: 0.0, 上限: 1000
# 反应: CFAS180G, 下限: 0.0, 上限: 1000
# 反应: CGLYabcpp, 下限: 0.0, 上限: 1000
# 反应: CGLYtex, 下限: -999999.0, 上限: 1000
# 反应: CHLabcpp, 下限: 0.0, 上限: 1000
# 反应: CHLtex, 下限: -999999.0, 上限: 1000
# 反应: CHOLD, 下限: 0.0, 上限: 1000
# 反应: CHOLSH, 下限: 0.0, 上限: 1000
# 反应: CHOLS_ex, 下限: -999999.0, 上限: 1000
# 反应: CHOLSabc, 下限: 0.0, 上限: 1000
# 反应: CPPPGO2, 下限: 0.0, 上限: 1000
# 反应: CREAT, 下限: 0.0, 上限: 1000
# 反应: CREATtex, 下限: -999999.0, 上限: 1000
# 反应: CREATtpp, 下限: -999999.0, 上限: 1000
# 反应: CRNDH, 下限: 0.0, 上限: 1000
# 反应: CRNabcpp, 下限: 0.0, 上限: 1000
# 反应: CRNtex, 下限: -999999.0, 上限: 1000
# 反应: CRO2t3pp, 下限: 0.0, 上限: 1000
# 反应: CRO2tex, 下限: -999999.0, 上限: 1000
# 反应: CRO2tpp, 下限: 0.0, 上限: 1000
# 反应: CRO4Rx, 下限: 0.0, 上限: 1000
# 反应: CRO4Ry, 下限: 0.0, 上限: 1000
# 反应: CRO4abcpp, 下限: 0.0, 上限: 1000
# 反应: CRO4t3pp, 下限: 0.0, 上限: 1000
# 反应: CRO4tex, 下限: -999999.0, 上限: 1000
# 反应: CRTNIH, 下限: 0.0, 上限: 1000
# 反应: CRTNtex, 下限: -999999.0, 上限: 1000
# 反应: CRTNtpp, 下限: -999999.0, 上限: 1000
# 反应: CS, 下限: 0.0, 上限: 1000
# 反应: CSND, 下限: 0.0, 上限: 1000
# 反应: CSNt2pp, 下限: 0.0, 上限: 1000
# 反应: CSNtex, 下限: -999999.0, 上限: 1000
# 反应: CSPMDDC, 下限: 0.0, 上限: 1000
# 反应: CSPMDDH, 下限: 0.0, 上限: 1000
# 反应: CTI1, 下限: -999999.0, 上限: 1000
# 反应: CTPS2, 下限: 0.0, 上限: 1000
# 反应: CU2abcpp, 下限: 0.0, 上限: 1000
# 反应: CU2t4pp, 下限: 0.0, 上限: 1000
# 反应: CU2tex, 下限: -999999.0, 上限: 1000
# 反应: CU2tonex, 下限: 0.0, 上限: 1000
# 反应: CU2tpp, 下限: 0.0, 上限: 1000
# 反应: CUt3, 下限: 0.0, 上限: 1000
# 反应: CUtex, 下限: -999999.0, 上限: 1000
# 反应: CUt2pp, 下限: -999999.0, 上限: 1000
# 反应: CYANST, 下限: 0.0, 上限: 1000
# 反应: CYANt2pp, 下限: 0.0, 上限: 1000
# 反应: CYANtex, 下限: -999999.0, 上限: 1000
# 反应: CYO1_KT, 下限: 0.0, 上限: 1000
# 反应: CYO4pp, 下限: 0.0, 上限: 1000
# 反应: CYRDAAT, 下限: 0.0, 上限: 1000
# 反应: CYRDAR, 下限: 0.0, 上限: 1000
# 反应: CYSDS, 下限: 0.0, 上限: 1000
# 反应: CYSDabcpp, 下限: 0.0, 上限: 1000
# 反应: CYSDtex, 下限: -999999.0, 上限: 1000
# 反应: CYSS, 下限: 0.0, 上限: 1000
# 反应: SLCYSS, 下限: 0.0, 上限: 1000
# 反应: CYSSADS, 下限: 0.0, 上限: 1000
# 反应: CYSTGL, 下限: 0.0, 上限: 1000
# 反应: CYSTL, 下限: 0.0, 上限: 1000
# 反应: CYSTRS, 下限: 0.0, 上限: 1000
# 反应: CYSTS, 下限: 0.0, 上限: 1000
# 反应: CYSabcpp, 下限: 0.0, 上限: 1000
# 反应: CYStex, 下限: -999999.0, 上限: 1000
# 反应: CYStpp, 下限: 0.0, 上限: 1000
# 反应: CYTBDpp, 下限: 0.0, 上限: 1000
# 反应: CYTBO3_4pp, 下限: 0.0, 上限: 1000
# 反应: CYTCAA3pp, 下限: 0.0, 上限: 1000
# 反应: CYTCBB3pp, 下限: 0.0, 上限: 1000
# 反应: CYTDH, 下限: 0.0, 上限: 1000
# 反应: CYTK1, 下限: -999999.0, 上限: 1000
# 反应: CYTK2, 下限: -999999.0, 上限: 1000
# 反应: DAAD, 下限: 0.0, 上限: 1000
# 反应: DH3MCHCDH, 下限: 0.0, 上限: 1000
# 反应: DH4MCHCDH, 下限: 0.0, 上限: 1000
# 反应: DHACOAH, 下限: -999999.0, 上限: 1000
# 反应: DHAD1_copy1, 下限: 0.0, 上限: 1000
# 反应: DHAD2, 下限: 0.0, 上限: 1000
# 反应: DHDPRy, 下限: 0.0, 上限: 1000
# 反应: DHDPS, 下限: 0.0, 上限: 1000
# 反应: DHFR, 下限: -999999.0, 上限: 1000
# 反应: DHFS, 下限: 0.0, 上限: 1000
# 反应: DHMPTR, 下限: 0.0, 上限: 1000
# 反应: DHMPTRx, 下限: 0.0, 上限: 1000
# 反应: DHNPA_1, 下限: 0.0, 上限: 1000
# 反应: DHNPTE, 下限: -999999.0, 上限: 1000
# 反应: DHORD2, 下限: 0.0, 上限: 1000
# 反应: DHORDfum, 下限: 0.0, 上限: 1000
# 反应: DHORTS, 下限: -999999.0, 上限: 1000
# 反应: DHPM1, 下限: 0.0, 上限: 1000
# 反应: DHPM2, 下限: 0.0, 上限: 1000
# 反应: DHPPDA2, 下限: 0.0, 上限: 1000
# 反应: DHPS, 下限: 0.0, 上限: 1000
# 反应: DHQTi_copy1, 下限: -999999.0, 上限: 1000
# 反应: DHQS, 下限: 0.0, 上限: 1000
# 反应: DHSKDH, 下限: 0.0, 上限: 1000
# 反应: DKGLCNR3, 下限: 0.0, 上限: 1000
# 反应: DLASNR, 下限: -999999.0, 上限: 1000
# 反应: DLCYSR, 下限: -999999.0, 上限: 1000
# 反应: DLEUabcpp, 下限: 0.0, 上限: 1000
# 反应: DLEUtex, 下限: -999999.0, 上限: 1000
# 反应: DLMETR, 下限: -999999.0, 上限: 1000
# 反应: DLYSAD, 下限: 0.0, 上限: 1000
# 反应: DLYSOXGAT, 下限: -999999.0, 上限: 1000
# 反应: DLYSPYRAT, 下限: -999999.0, 上限: 1000
# 反应: DLYSabcpp, 下限: 0.0, 上限: 1000
# 反应: DLYStex, 下限: -999999.0, 上限: 1000
# 反应: DMATT, 下限: 0.0, 上限: 1000
# 反应: METDtex, 下限: -999999.0, 上限: 1000
# 反应: DMGDH2, 下限: -999999.0, 上限: 1000
# 反应: DMGLYBabcpp, 下限: 0.0, 上限: 1000
# 反应: DMGLYtex, 下限: -999999.0, 上限: 1000
# 反应: DMPPS, 下限: 0.0, 上限: 1000
# 反应: DMQMT, 下限: 0.0, 上限: 1000
# 反应: DMSO2abcpp, 下限: 0.0, 上限: 1000
# 反应: DMSO2tex, 下限: -999999.0, 上限: 1000
# 反应: DM_5drib_c, 下限: 0.0, 上限: 1000
# 反应: DM_amob_c, 下限: 0.0, 上限: 1000
# 反应: DM_C100aPHA_c, 下限: 0.0, 上限: 1000
# 反应: DM_C100pPHA_c, 下限: 0.0, 上限: 1000
# 反应: DM_C101PAH_c, 下限: 0.0, 上限: 1000
# 反应: DM_C120aPHA_c, 下限: 0.0, 上限: 1000
# 反应: DM_C121aPHA_c, 下限: 0.0, 上限: 1000
# 反应: DM_C121d6PHA_c, 下限: 0.0, 上限: 1000
# 反应: DM_C140aPHA_c, 下限: 0.0, 上限: 1000
# 反应: DM_C141aPHA_c, 下限: 0.0, 上限: 1000
# 反应: DM_C141d5PHA_c, 下限: 0.0, 上限: 1000
# 反应: DM_C142PHA_c, 下限: 0.0, 上限: 1000
# 反应: DM_C40aPHA_c, 下限: 0.0, 上限: 1000
# 反应: DM_C40atPHA_c, 下限: 0.0, 上限: 1000
# 反应: DM_C40pPHA_c, 下限: 0.0, 上限: 1000
# 反应: DM_C50aPHA_c, 下限: 0.0, 上限: 1000
# 反应: DM_C50pPHA_c, 下限: 0.0, 上限: 1000
# 反应: DM_C60aPHA_c, 下限: 0.0, 上限: 1000
# 反应: DM_C60atPHA_c, 下限: 0.0, 上限: 1000
# 反应: DM_C60pPHA_c, 下限: 0.0, 上限: 1000
# 反应: ECOAH20, 下限: -999999.0, 上限: 1000
# 反应: ECOAH21, 下限: -999999.0, 上限: 1000
# 反应: ECOAH22, 下限: -999999.0, 上限: 1000
# 反应: ECOAH23, 下限: -999999.0, 上限: 1000
# 反应: ECOAH24, 下限: -999999.0, 上限: 1000
# 反应: ECOAH25, 下限: -999999.0, 上限: 1000
# 反应: ECOAH26, 下限: -999999.0, 上限: 1000
# 反应: ECOAH27, 下限: -999999.0, 上限: 1000
# 反应: ECOAH28, 下限: -999999.0, 上限: 1000
# 反应: ECOAH29, 下限: -999999.0, 上限: 1000
# 反应: ECOAH3, 下限: -999999.0, 上限: 1000
# 反应: ECOAH30, 下限: -999999.0, 上限: 1000
# 反应: ECOAH31, 下限: -999999.0, 上限: 1000
# 反应: ECOAH32, 下限: -999999.0, 上限: 1000
# 反应: ECOAH33, 下限: -999999.0, 上限: 1000
# 反应: ECOAH34, 下限: -999999.0, 上限: 1000
# 反应: ECOAH35, 下限: -999999.0, 上限: 1000
# 反应: ECOAH36, 下限: -999999.0, 上限: 1000
# 反应: ECOAH37, 下限: -999999.0, 上限: 1000
# 反应: ECOAH38, 下限: -999999.0, 上限: 1000
# 反应: ECOAH4, 下限: -999999.0, 上限: 1000
# 反应: ECOAH5, 下限: -999999.0, 上限: 1000
# 反应: ECOAH6, 下限: -999999.0, 上限: 1000
# 反应: ECOAH7, 下限: -999999.0, 上限: 1000
# 反应: ECOAH8, 下限: -999999.0, 上限: 1000
# 反应: ECOAH9ir, 下限: 0.0, 上限: 1000
# 反应: ECTOH, 下限: 0.0, 上限: 1000
# 反应: ECTOabcpp, 下限: 0.0, 上限: 1000
# 反应: ECTOtex, 下限: -999999.0, 上限: 1000
# 反应: EDA, 下限: 0.0, 上限: 1000
# 反应: EDD, 下限: 0.0, 上限: 1000
# 反应: EDTXS1_kt, 下限: 0.0, 上限: 1000
# 反应: EDTXS2_kt, 下限: 0.0, 上限: 1000
# 反应: EDTXS5_kt, 下限: 0.0, 上限: 1000
# 反应: EDTXS6_kt, 下限: 0.0, 上限: 1000
# 反应: EGMEACPR, 下限: 0.0, 上限: 1000
# 反应: ENO, 下限: -999999.0, 上限: 1000
# 反应: EPMEACPR, 下限: 0.0, 上限: 1000
# 反应: ETHAAL, 下限: 0.0, 上限: 1000
# 反应: ETHAt2pp, 下限: 0.0, 上限: 1000
# 反应: ETHAtex, 下限: -999999.0, 上限: 1000
# 反应: ETHSO3abcpp, 下限: 0.0, 上限: 1000
# 反应: ETHSO3tex, 下限: -999999.0, 上限: 1000
# 反应: ETOHtex, 下限: -999999.0, 上限: 1000
# 反应: ETOHtrpp, 下限: -999999.0, 上限: 1000
# 反应: EX_12dgr160_e, 下限: 0.0, 上限: 1000
# 反应: EX_12dgr180_e, 下限: 0.0, 上限: 1000
# 反应: EX_13dampp_e, 下限: 0.0, 上限: 1000
# 反应: EX_15dap_e, 下限: 0.0, 上限: 1000
# 反应: EX_1ag160_e, 下限: 0.0, 上限: 1000
# 反应: EX_1ag180_e, 下限: 0.0, 上限: 1000
# 反应: EX_1ag181d9_e, 下限: 0.0, 上限: 1000
# 反应: EX_1ag182d9d12_e, 下限: 0.0, 上限: 1000
# 反应: EX_25dkglcn_e, 下限: 0.0, 上限: 1000
# 反应: EX_26dap__M_e, 下限: 0.0, 上限: 1000
# 反应: EX_AEP_e, 下限: 0.0, 上限: 1000
# 反应: EX_2ddglcn_e, 下限: 0.0, 上限: 1000
# 反应: EX_2dhglcn_e, 下限: 0.0, 上限: 1000
# 反应: EX_2m35mdntha_e, 下限: 0.0, 上限: 1000
# 反应: EX_34dhbz_e, 下限: 0.0, 上限: 1000
# 反应: EX_34dhcinm_e, 下限: 0.0, 上限: 1000
# 反应: EX_34dhphe_e, 下限: 0.0, 上限: 1000
# 反应: EX_35dnta_e, 下限: 0.0, 上限: 1000
# 反应: EX_3h4atb_e, 下限: 0.0, 上限: 1000
# 反应: EX_3mb_e, 下限: 0.0, 上限: 1000
# 反应: EX_btd_RR_e, 下限: 0.0, 上限: 1000
# 反应: EX_btn_e, 下限: 0.0, 上限: 1000
# 反应: EX_butso3_e, 下限: 0.0, 上限: 1000
# 反应: EX_bz_e, 下限: 0.0, 上限: 1000
# 反应: EX_ca2_e, 下限: -10.0, 上限: 1000
# 反应: EX_carn_e, 下限: 0.0, 上限: 1000
# 反应: EX_catechol_e, 下限: 0.0, 上限: 1000
# 反应: EX_cbi_e, 下限: 0.0, 上限: 1000
# 反应: EX_cbl1_e, 下限: 0.0, 上限: 1000
# 反应: EX_cd2_e, 下限: 0.0, 上限: 1000
# 反应: EX_cell4_e, 下限: 0.0, 上限: 1000
# 反应: EX_cgly_e, 下限: 0.0, 上限: 1000
# 反应: EX_chol_e, 下限: 0.0, 上限: 1000
# 反应: EX_chols_e, 下限: 0.0, 上限: 1000
# 反应: EX_chor_e, 下限: 0.0, 上限: 1000
# 反应: EX_cinnm_e, 下限: 0.0, 上限: 1000
# 反应: EX_cit_e, 下限: 0.0, 上限: 1000
# 反应: EX_cl_e, 下限: -10.0, 上限: 1000
# 反应: EX_cm_e, 下限: 0.0, 上限: 1000
# 反应: EX_cmcbtt_e, 下限: 0.0, 上限: 1000
# 反应: EX_co2_e, 下限: -100.0, 上限: 1000
# 反应: EX_co_e, 下限: 0.0, 上限: 1000
# 反应: EX_cobalt2_e, 下限: -10.0, 上限: 1000
# 反应: EX_confrl_e, 下限: 0.0, 上限: 1000
# 反应: EX_creat_e, 下限: 0.0, 上限: 1000
# 反应: EX_crn_e, 下限: 0.0, 上限: 1000
# 反应: EX_cro2_e, 下限: 0.0, 上限: 1000
# 反应: EX_cro4_e, 下限: 0.0, 上限: 1000
# 反应: EX_crtn_e, 下限: 0.0, 上限: 1000
# 反应: EX_csn_e, 下限: 0.0, 上限: 1000
# 反应: EX_cu2_e, 下限: -10.0, 上限: 1000
# 反应: EX_cu_e, 下限: 0.0, 上限: 1000
# 反应: EX_cyan_e, 下限: 0.0, 上限: 1000
# 反应: EX_cys__D_e, 下限: 0.0, 上限: 1000
# 反应: EX_cys__L_e, 下限: 0.0, 上限: 1000
# 反应: EX_dag181d9_e, 下限: 0.0, 上限: 1000
# 反应: EX_dag182d9d12_e, 下限: 0.0, 上限: 1000
# 反应: EX_dca_e, 下限: 0.0, 上限: 1000
# 反应: EX_ddca_e, 下限: 0.0, 上限: 1000
# 反应: EX_dgudbutn_e, 下限: 0.0, 上限: 1000
# 反应: EX_dmanur_e, 下限: 0.0, 上限: 1000
# 反应: EX_dmgly_e, 下限: 0.0, 上限: 1000
# 反应: EX_dmso2_e, 下限: 0.0, 上限: 1000
# 反应: EX_dopa_e, 下限: 0.0, 上限: 1000
# 反应: EX_ecto__L_e, 下限: 0.0, 上限: 1000
# 反应: EX_enter_e, 下限: 0.0, 上限: 1000
# 反应: EX_etha_e, 下限: 0.0, 上限: 1000
# 反应: EX_ethso3_e, 下限: 0.0, 上限: 1000
# 反应: EX_etoh_e, 下限: 0.0, 上限: 1000
# 反应: EX_fald_e, 下限: 0.0, 上限: 1000
# 反应: EX_fcmcbtt_e, 下限: 0.0, 上限: 1000
# 反应: EX_fe2_e, 下限: -10.0, 上限: 1000
# 反应: EX_fe3_e, 下限: 0.0, 上限: 1000
# 反应: EX_fe3dcit_e, 下限: 0.0, 上限: 1000
# 反应: EX_fe3mcbtt_e, 下限: 0.0, 上限: 1000
# 反应: EX_fe3pyovd_e, 下限: 0.0, 上限: 1000
# 反应: EX_fe3pyovd_kt_e, 下限: 0.0, 上限: 1000
# 反应: EX_fecrm_e, 下限: 0.0, 上限: 1000
# 反应: EX_fecrm_un_e, 下限: 0.0, 上限: 1000
# 反应: EX_feenter_e, 下限: 0.0, 上限: 1000
# 反应: EX_feoxam_e, 下限: 0.0, 上限: 1000
# 反应: EX_feoxam_un_e, 下限: 0.0, 上限: 1000
# 反应: EX_fer_e, 下限: 0.0, 上限: 1000
# 反应: EX_for_e, 下限: 0.0, 上限: 1000
# 反应: EX_fru_e, 下限: 0.0, 上限: 1000
# 反应: EX_fum_e, 下限: 0.0, 上限: 1000
# 反应: EX_ga_e, 下限: 0.0, 上限: 1000
# 反应: EX_galct__D_e, 下限: 0.0, 上限: 1000
# 反应: EX_galur_e, 下限: 0.0, 上限: 1000
# 反应: EX_glc__D_e, 下限: -6.0, 上限: 1000
# 反应: EX_glcn_e, 下限: 0.0, 上限: 1000
# 反应: EX_glcr_e, 下限: 0.0, 上限: 1000
# 反应: EX_glcur_e, 下限: 0.0, 上限: 1000
# 反应: EX_gln__L_e, 下限: 0.0, 上限: 1000
# 反应: EX_glu__L_e, 下限: 0.0, 上限: 1000
# 反应: EX_glutar_e, 下限: 0.0, 上限: 1000
# 反应: EX_gly_e, 下限: 0.0, 上限: 1000
# 反应: EX_glyald_e, 下限: 0.0, 上限: 1000
# 反应: EX_glyb_e, 下限: 0.0, 上限: 1000
# 反应: EX_glyc__R_e, 下限: 0.0, 上限: 1000
# 反应: EX_glyc_e, 下限: 0.0, 上限: 1000
# 反应: EX_glyclt_e, 下限: 0.0, 上限: 1000
# 反应: EX_glycol_e, 下限: 0.0, 上限: 1000
# 反应: EX_glygln_e, 下限: 0.0, 上限: 1000
# 反应: EX_glyglu_e, 下限: 0.0, 上限: 1000
# 反应: EX_glygly_e, 下限: 0.0, 上限: 1000
# 反应: EX_glymet_e, 下限: 0.0, 上限: 1000
# 反应: EX_glyphe_e, 下限: 0.0, 上限: 1000
# 反应: EX_glyser_e, 下限: 0.0, 上限: 1000
# 反应: EX_gua_e, 下限: 0.0, 上限: 1000
# 反应: EX_gudac_e, 下限: 0.0, 上限: 1000
# 反应: EX_gudptn_e, 下限: 0.0, 上限: 1000
# 反应: EX_h2o2_e, 下限: 0.0, 上限: 1000
# 反应: EX_h2o_e, 下限: -100.0, 上限: 1000
# 反应: EX_h2s_e, 下限: 0.0, 上限: 1000
# 反应: EX_h_e, 下限: -100.0, 上限: 1000
# 反应: EX_hco3_e, 下限: -10.0, 上限: 1000
# 反应: EX_hcys__L_e, 下限: 0.0, 上限: 1000
# 反应: EX_hdca_e, 下限: 0.0, 上限: 1000
# 反应: EX_hdcea_e, 下限: 0.0, 上限: 1000
# 反应: EX_hg2_e, 下限: 0.0, 上限: 1000
# 反应: EX_hgentis_e, 下限: 0.0, 上限: 1000
# 反应: EX_his__L_e, 下限: 0.0, 上限: 1000
# 反应: EX_hisgly_e, 下限: 0.0, 上限: 1000
# 反应: EX_hishis_e, 下限: 0.0, 上限: 1000
# 反应: EX_hom__L_e, 下限: 0.0, 上限: 1000
# 反应: EX_hpta_e, 下限: 0.0, 上限: 1000
# 反应: EX_hxa_e, 下限: 0.0, 上限: 1000
# 反应: EX_hxan_e, 下限: 0.0, 上限: 1000
# 反应: EX_icit_e, 下限: 0.0, 上限: 1000
# 反应: EX_ile__L_e, 下限: 0.0, 上限: 1000
# 反应: EX_ind3ac_e, 下限: 0.0, 上限: 1000
# 反应: EX_indole_e, 下限: 0.0, 上限: 1000
# 反应: EX_ins_e, 下限: 0.0, 上限: 1000
# 反应: EX_isetac_e, 下限: 0.0, 上限: 1000
# 反应: EX_k_e, 下限: -10.0, 上限: 1000
# 反应: EX_lac__D_e, 下限: 0.0, 上限: 1000
# 反应: EX_lac__L_e, 下限: 0.0, 上限: 1000
# 反应: EX_leu__D_e, 下限: 0.0, 上限: 1000
# 反应: EX_leu__L_e, 下限: 0.0, 上限: 1000
# 反应: EX_leuleu_e, 下限: 0.0, 上限: 1000
# 反应: EX_lnlc_e, 下限: 0.0, 上限: 1000
# 反应: EX_lpspput_e, 下限: 0.0, 上限: 1000
# 反应: EX_lys__D_e, 下限: 0.0, 上限: 1000
# 反应: EX_lys__L_e, 下限: 0.0, 上限: 1000
# 反应: EX_m_xyl_e, 下限: 0.0, 上限: 1000
# 反应: EX_mal__D_e, 下限: 0.0, 上限: 1000
# 反应: EX_mal__L_e, 下限: 0.0, 上限: 1000
# 反应: EX_man_e, 下限: 0.0, 上限: 1000
# 反应: EX_manur_e, 下限: 0.0, 上限: 1000
# 反应: EX_mcbtt_e, 下限: 0.0, 上限: 1000
# 反应: EX_meoh_e, 下限: 0.0, 上限: 1000
# 反应: EX_met__L_e, 下限: 0.0, 上限: 1000
# 反应: EX_mg2_e, 下限: -10.0, 上限: 1000
# 反应: EX_mmet_e, 下限: 0.0, 上限: 1000
# 反应: EX_mn2_e, 下限: -10.0, 上限: 1000
# 反应: EX_mobd_e, 下限: -10.0, 上限: 1000
# 反应: EX_mso3_e, 下限: 0.0, 上限: 1000
# 反应: EX_na1_e, 下限: -10.0, 上限: 1000
# 反应: EX_nac_e, 下限: 0.0, 上限: 1000
# 反应: EX_nh4_e, 下限: -30.0, 上限: 1000
# 反应: EX_ni2_e, 下限: -10.0, 上限: 1000
# 反应: EX_no2_e, 下限: 0.0, 上限: 1000
# 反应: EX_no3_e, 下限: 0.0, 上限: 1000
# 反应: EX_no_e, 下限: 0.0, 上限: 1000
# 反应: EX_nona_e, 下限: 0.0, 上限: 1000
# 反应: EX_o2_e, 下限: -100.0, 上限: 1000
# 反应: EX_o_xyl_e, 下限: 0.0, 上限: 1000
# 反应: EX_oaa_e, 下限: 0.0, 上限: 1000
# 反应: EX_ocdca_e, 下限: 0.0, 上限: 1000
# 反应: EX_ocdcea_e, 下限: 0.0, 上限: 1000
# 反应: EX_octa_e, 下限: 0.0, 上限: 1000
# 反应: EX_orn__D_e, 下限: 0.0, 上限: 1000
# 反应: EX_orn_e, 下限: 0.0, 上限: 1000
# 反应: EX_orot_e, 下限: 0.0, 上限: 1000
# 反应: EX_oxa_e, 下限: 0.0, 上限: 1000
# 反应: EX_5g2oxpt_e, 下限: 0.0, 上限: 1000
# 反应: EX_p_xyl_e, 下限: 0.0, 上限: 1000
# 反应: EX_pac_e, 下限: 0.0, 上限: 1000
# 反应: EX_pacald_e, 下限: 0.0, 上限: 1000
# 反应: EX_pb2_e, 下限: 0.0, 上限: 1000
# 反应: EX_pea_e, 下限: 0.0, 上限: 1000
# 反应: EX_peamn_e, 下限: 0.0, 上限: 1000
# 反应: EX_pentso3_e, 下限: 0.0, 上限: 1000
# 反应: EX_phe__D_e, 下限: 0.0, 上限: 1000
# 反应: EX_phe__L_e, 下限: 0.0, 上限: 1000
# 反应: EX_phedca_e, 下限: 0.0, 上限: 1000
# 反应: EX_phehpa_e, 下限: 0.0, 上限: 1000
# 反应: EX_phehxa_e, 下限: 0.0, 上限: 1000
# 反应: EX_pheme_e, 下限: 0.0, 上限: 1000
# 反应: EX_phenona_e, 下限: 0.0, 上限: 1000
# 反应: EX_pheocta_e, 下限: 0.0, 上限: 1000
# 反应: EX_phept_e, 下限: 0.0, 上限: 1000
# 反应: EX_phpyr_e, 下限: 0.0, 上限: 1000
# 反应: EX_pi_e, 下限: -10.0, 上限: 1000
# 反应: EX_pnto__R_e, 下限: 0.0, 上限: 1000
# 反应: EX_ppa_e, 下限: 0.0, 上限: 1000
# 反应: EX_ppi_e, 下限: 0.0, 上限: 1000
# 反应: EX_prealg_MG_14_e, 下限: 0.0, 上限: 1000
# 反应: EX_prealg_MG_23_e, 下限: 0.0, 上限: 1000
# 反应: EX_prealg_MG_32_e, 下限: 0.0, 上限: 1000
# 反应: EX_prealg_MG_41_e, 下限: 0.0, 上限: 1000
# 反应: EX_prealginate_G_e, 下限: 0.0, 上限: 1000
# 反应: EX_pro__D_e, 下限: 0.0, 上限: 1000
# 反应: EX_pro__L_e, 下限: 0.0, 上限: 1000
# 反应: EX_progly_e, 下限: 0.0, 上限: 1000
# 反应: EX_pta_e, 下限: 0.0, 上限: 1000
# 反应: EX_ptrc_e, 下限: 0.0, 上限: 1000
# 反应: EX_ptsla_e, 下限: 0.0, 上限: 1000
# 反应: EX_pydam_e, 下限: 0.0, 上限: 1000
# 反应: EX_pyovd_e, 下限: 0.0, 上限: 1000
# 反应: EX_pyovd_kt_e, 下限: 0.0, 上限: 1000
# 反应: EX_pyr_e, 下限: 0.0, 上限: 1000
# 反应: EX_quin_e, 下限: 0.0, 上限: 1000
# 反应: EX_rib__D_e, 下限: 0.0, 上限: 1000
# 反应: EX_sbo3_e, 下限: 0.0, 上限: 1000
# 反应: EX_sel_e, 下限: -10.0, 上限: 1000
# 反应: EX_ser__D_e, 下限: 0.0, 上限: 1000
# 反应: EX_ser__L_e, 下限: 0.0, 上限: 1000
# 反应: EX_sheme_e, 下限: 0.0, 上限: 1000
# 反应: EX_skm_e, 下限: 0.0, 上限: 1000
# 反应: EX_so2_e, 下限: 0.0, 上限: 1000
# 反应: EX_so3_e, 下限: 0.0, 上限: 1000
# 反应: EX_so4_e, 下限: -10.0, 上限: 1000
# 反应: EX_spmd_e, 下限: 0.0, 上限: 1000
# 反应: EX_succ_e, 下限: 0.0, 上限: 1000
# 反应: EX_sulfac_e, 下限: 0.0, 上限: 1000
# 反应: EX_tag160_e, 下限: 0.0, 上限: 1000
# 反应: EX_tag180_e, 下限: 0.0, 上限: 1000
# 反应: EX_tag181d9_e, 下限: 0.0, 上限: 1000
# 反应: EX_tag182d9d12_e, 下限: 0.0, 上限: 1000
# 反应: EX_taur_e, 下限: 0.0, 上限: 1000
# 反应: EX_tcynt_e, 下限: 0.0, 上限: 1000
# 反应: EX_thr__L_e, 下限: 0.0, 上限: 1000
# 反应: EX_thym_e, 下限: 0.0, 上限: 1000
# 反应: EX_tmanur_e, 下限: 0.0, 上限: 1000
# 反应: EX_tnt_e, 下限: 0.0, 上限: 1000
# 反应: EX_tol_e, 下限: 0.0, 上限: 1000
# 反应: EX_trp__L_e, 下限: 0.0, 上限: 1000
# 反应: EX_tsul_e, 下限: 0.0, 上限: 1000
# 反应: EX_ttdca_e, 下限: 0.0, 上限: 1000
# 反应: EX_ttdcea_e, 下限: 0.0, 上限: 1000
# 反应: EX_ttrcyc_e, 下限: 0.0, 上限: 1000
# 反应: EX_tungs_e, 下限: -10.0, 上限: 1000
# 反应: EX_tyr__D_e, 下限: 0.0, 上限: 1000
# 反应: EX_tyr__L_e, 下限: 0.0, 上限: 1000
# 反应: EX_ura_e, 下限: 0.0, 上限: 1000
# 反应: EX_urea_e, 下限: 0.0, 上限: 1000
# 反应: EX_uri_e, 下限: 0.0, 上限: 1000
# 反应: EX_vacc_e, 下限: 0.0, 上限: 1000
# 反应: EX_val__D_e, 下限: 0.0, 上限: 1000
# 反应: EX_val__L_e, 下限: 0.0, 上限: 1000
# 反应: EX_vanln_e, 下限: 0.0, 上限: 1000
# 反应: EX_vanlt_e, 下限: 0.0, 上限: 1000
# 反应: EX_xan_e, 下限: 0.0, 上限: 1000
# 反应: EX_zn2_e, 下限: -10.0, 上限: 1000
# 反应: FA100ACPHi, 下限: 0.0, 上限: 1000
# 反应: FA120ACPHi, 下限: 0.0, 上限: 1000
# 反应: FA140ACPHi, 下限: 0.0, 上限: 1000
# 反应: FA141ACPHi, 下限: 0.0, 上限: 1000
# 反应: FA160ACPHi, 下限: 0.0, 上限: 1000
# 反应: FA161ACPHi, 下限: 0.0, 上限: 1000
# 反应: FA80ACPHi, 下限: 0.0, 上限: 1000
# 反应: FACOAE100, 下限: 0.0, 上限: 1000
# 反应: FACOAE120, 下限: 0.0, 上限: 1000
# 反应: FACOAE140, 下限: 0.0, 上限: 1000
# 反应: FACOAE141, 下限: 0.0, 上限: 1000
# 反应: FACOAE160, 下限: 0.0, 上限: 1000
# 反应: FACOAE161, 下限: 0.0, 上限: 1000
# 反应: FACOAE180, 下限: 0.0, 上限: 1000
# 反应: FACOAE181, 下限: 0.0, 上限: 1000
# 反应: HMR_0260, 下限: 0.0, 上限: 1000
# 反应: FACOAE1829Z12Z, 下限: 0.0, 上限: 1000
# 反应: FACOAE50, 下限: 0.0, 上限: 1000
# 反应: FACOAE60, 下限: 0.0, 上限: 1000
# 反应: FACOAE70, 下限: 0.0, 上限: 1000
# 反应: FACOAE80, 下限: 0.0, 上限: 1000
# 反应: FACOAE90, 下限: 0.0, 上限: 1000
# 反应: HMR_0180_copy1, 下限: 0.0, 上限: 1000
# 反应: FACOAL100t2pp, 下限: 0.0, 上限: 1000
# 反应: HMR_0188, 下限: 0.0, 上限: 1000
# 反应: FACOAL120t2pp, 下限: 0.0, 上限: 1000
# 反应: FACOAL140, 下限: 0.0, 上限: 1000
# 反应: FACOAL140t2pp, 下限: 0.0, 上限: 1000
# 反应: FACOAL141, 下限: 0.0, 上限: 1000
# 反应: FACOAL141t2pp, 下限: 0.0, 上限: 1000
# 反应: FACOAL160, 下限: 0.0, 上限: 1000
# 反应: FACOAL160t2pp, 下限: 0.0, 上限: 1000
# 反应: FACOAL161, 下限: 0.0, 上限: 1000
# 反应: FACOAL161t2pp, 下限: 0.0, 上限: 1000
# 反应: FACOAL180, 下限: 0.0, 上限: 1000
# 反应: FACOAL180t2pp, 下限: 0.0, 上限: 1000
# 反应: FACOAL1812, 下限: 0.0, 上限: 1000
# 反应: FACOAL181d11tpp, 下限: 0.0, 上限: 1000
# 反应: FACOAL181d6t2pp, 下限: 0.0, 上限: 1000
# 反应: FACOAL181, 下限: 0.0, 上限: 1000
# 反应: FACOAL181t2pp, 下限: 0.0, 上限: 1000
# 反应: FACOAL1821, 下限: 0.0, 上限: 1000
# 反应: FACOAL182t2pp, 下限: 0.0, 上限: 1000
# 反应: FACOAL50i, 下限: 0.0, 上限: 1000
# 反应: FACOAL50t2pp, 下限: 0.0, 上限: 1000
# 反应: FACOAL60i, 下限: 0.0, 上限: 1000
# 反应: FACOAL60t2pp, 下限: 0.0, 上限: 1000
# 反应: FACOAL_70_c, 下限: 0.0, 上限: 1000
# 反应: FACOAL70t2pp, 下限: 0.0, 上限: 1000
# 反应: FACOAL80, 下限: 0.0, 上限: 1000
# 反应: FACOAL80t2pp, 下限: 0.0, 上限: 1000
# 反应: FACOAL90i, 下限: 0.0, 上限: 1000
# 反应: FACOAL90t2pp, 下限: 0.0, 上限: 1000
# 反应: FACOALP100t2pp, 下限: 0.0, 上限: 1000
# 反应: FACOALP50t2pp, 下限: 0.0, 上限: 1000
# 反应: FACOALP60t2pp, 下限: 0.0, 上限: 1000
# 反应: FACOALP70t2pp, 下限: 0.0, 上限: 1000
# 反应: FACOALP80t2pp, 下限: 0.0, 上限: 1000
# 反应: FACOALP90t2pp, 下限: 0.0, 上限: 1000
# 反应: FACOALT60t2pp, 下限: 0.0, 上限: 1000
# 反应: FALDH2, 下限: -999999.0, 上限: 1000
# 反应: FALDM, 下限: -999999.0, 上限: 1000
# 反应: FALDep, 下限: 0.0, 上限: 1000
# 反应: FALDtex, 下限: -999999.0, 上限: 1000
# 反应: FALDtpp, 下限: -999999.0, 上限: 1000
# 反应: FALDtpp2, 下限: 0.0, 上限: 1000
# 反应: PPAtex, 下限: -999999.0, 上限: 1000
# 反应: FALGTHLs, 下限: -999999.0, 上限: 1000
# 反应: FBA, 下限: -999999.0, 上限: 1000
# 反应: FBACS, 下限: 0.0, 上限: 1000
# 反应: FBACabcpp, 下限: 0.0, 上限: 1000
# 反应: FBP, 下限: 0.0, 上限: 1000
# 反应: FCLT, 下限: 0.0, 上限: 1000
# 反应: FCOAHA, 下限: 0.0, 上限: 1000
# 反应: FDH, 下限: 0.0, 上限: 1000
# 反应: FDMO, 下限: 0.0, 上限: 1000
# 反应: FDMO2, 下限: 0.0, 上限: 1000
# 反应: FDMO3, 下限: 0.0, 上限: 1000
# 反应: FDMO4, 下限: 0.0, 上限: 1000
# 反应: FDMO5, 下限: 0.0, 上限: 1000
# 反应: FDMO6, 下限: 0.0, 上限: 1000
# 反应: FDMO7, 下限: 0.0, 上限: 1000
# 反应: FDMOtau, 下限: 0.0, 上限: 1000
# 反应: FE2t3pp, 下限: 0.0, 上限: 1000
# 反应: FE2tex, 下限: -999999.0, 上限: 1000
# 反应: FE3DCIT2abcpp, 下限: 0.0, 上限: 1000
# 反应: FE3DCITCH, 下限: -999999.0, 上限: 1000
# 反应: FE3DCITR, 下限: 0.0, 上限: 1000
# 反应: FE3DCITR2, 下限: 0.0, 上限: 1000
# 反应: FE3DCITR3, 下限: 0.0, 上限: 1000
# 反应: FE3DCITR4, 下限: 0.0, 上限: 1000
# 反应: FE3DCITabcpp, 下限: 0.0, 上限: 1000
# 反应: FE3DCITtonex, 下限: 0.0, 上限: 1000
# 反应: FE3PYOVD2tonex, 下限: 0.0, 上限: 1000
# 反应: FE3PYOVDDR, 下限: -999999.0, 上限: 1000
# 反应: FE3PYOVDDR2, 下限: -999999.0, 上限: 1000
# 反应: FE3PYOVDL, 下限: -999999.0, 上限: 1000
# 反应: FE3PYOVDL2, 下限: -999999.0, 上限: 1000
# 反应: FE3PYOVDtonex, 下限: 0.0, 上限: 1000
# 反应: FE3abcpp, 下限: 0.0, 上限: 1000
# 反应: FECRMR1, 下限: 0.0, 上限: 1000
# 反应: FECRMR2, 下限: 0.0, 上限: 1000
# 反应: FECRMUtex, 下限: 0.0, 上限: 1000
# 反应: FECRMUtpp, 下限: 0.0, 上限: 1000
# 反应: FECRMabcpp, 下限: 0.0, 上限: 1000
# 反应: FECRMexs, 下限: 0.0, 上限: 1000
# 反应: FECRMtonex, 下限: 0.0, 上限: 1000
# 反应: FEENTERR1, 下限: 0.0, 上限: 1000
# 反应: FEENTERR2, 下限: 0.0, 上限: 1000
# 反应: FEENTERabcpp, 下限: 0.0, 上限: 1000
# 反应: FEENTERexs, 下限: 0.0, 上限: 1000
# 反应: FEENTERtex, 下限: 0.0, 上限: 1000
# 反应: FEENTERtonex, 下限: 0.0, 上限: 1000
# 反应: FEENTERtpp, 下限: 0.0, 上限: 1000
# 反应: FEOXAMR1, 下限: 0.0, 上限: 1000
# 反应: FEOXAMR2, 下限: 0.0, 上限: 1000
# 反应: FEOXAMUtex, 下限: 0.0, 上限: 1000
# 反应: FEOXAMUtpp, 下限: 0.0, 上限: 1000
# 反应: FEOXAMabcpp, 下限: 0.0, 上限: 1000
# 反应: FEOXAMexs, 下限: 0.0, 上限: 1000
# 反应: GAt1, 下限: -999999.0, 上限: 1000
# 反应: FEOXAMtonex, 下限: 0.0, 上限: 1000
# 反应: FEROpp, 下限: 0.0, 上限: 1000
# 反应: FERULCOAS, 下限: 0.0, 上限: 1000
# 反应: FERtex, 下限: -999999.0, 上限: 1000
# 反应: FERtpp, 下限: -999999.0, 上限: 1000
# 反应: FLDR2, 下限: 0.0, 上限: 1000
# 反应: FMETTRS, 下限: 0.0, 上限: 1000
# 反应: FMNAT, 下限: 0.0, 上限: 1000
# 反应: FMNRx2_copy1, 下限: -999999.0, 上限: 1000
# 反应: FMNRx, 下限: 0.0, 上限: 1000
# 反应: FMNRx2_copy2, 下限: 0.0, 上限: 1000
# 反应: FOLD3, 下限: 0.0, 上限: 1000
# 反应: FORGLUIH2, 下限: 0.0, 上限: 1000
# 反应: FORt2pp, 下限: 0.0, 上限: 1000
# 反应: FORtex, 下限: -999999.0, 上限: 1000
# 反应: FRDO4r, 下限: -999999.0, 上限: 1000
# 反应: FRDO5r, 下限: -999999.0, 上限: 1000
# 反应: FRDO6r, 下限: -999999.0, 上限: 1000
# 反应: FRDO7r, 下限: -999999.0, 上限: 1000
# 反应: FRUK, 下限: 0.0, 上限: 1000
# 反应: FRUptspp, 下限: 0.0, 上限: 1000
# 反应: FRUtex, 下限: -999999.0, 上限: 1000
# 反应: FTHFCL, 下限: 0.0, 上限: 1000
# 反应: FTHFD, 下限: 0.0, 上限: 1000
# 反应: FUM, 下限: -999999.0, 上限: 1000
# 反应: FUMAC, 下限: 0.0, 上限: 1000
# 反应: FUMt2_2pp, 下限: 0.0, 上限: 1000
# 反应: FUMtex, 下限: -999999.0, 上限: 1000
# 反应: G1PACT, 下限: 0.0, 上限: 1000
# 反应: G1PTT, 下限: 0.0, 上限: 1000
# 反应: G1SAT, 下限: -999999.0, 上限: 1000
# 反应: G2PP, 下限: 0.0, 上限: 1000
# 反应: G3PAT120, 下限: 0.0, 上限: 1000
# 反应: G3PAT140, 下限: 0.0, 上限: 1000
# 反应: G3PAT141, 下限: 0.0, 上限: 1000
# 反应: G3PAT160, 下限: 0.0, 上限: 1000
# 反应: G3PAT161, 下限: 0.0, 上限: 1000
# 反应: G3PAT180, 下限: 0.0, 上限: 1000
# 反应: G3PAT181, 下限: 0.0, 上限: 1000
# 反应: G3PD2, 下限: -999999.0, 上限: 1000
# 反应: G3PD5, 下限: 0.0, 上限: 1000
# 反应: G3PEabcpp, 下限: 0.0, 上限: 1000
# 反应: G3PGabcpp, 下限: 0.0, 上限: 1000
# 反应: G5SADs, 下限: 0.0, 上限: 1000
# 反应: G5SD_copy1, 下限: 0.0, 上限: 1000
# 反应: G6PBDH, 下限: 0.0, 上限: 1000
# 反应: G6PDH2r, 下限: 0.0, 上限: 1000
# 反应: G6PI, 下限: -999999.0, 上限: 1000
# 反应: GACH, 下限: 0.0, 上限: 1000
# 反应: GAD2ktpp, 下限: -999999.0, 上限: 1000
# 反应: GADOX, 下限: 0.0, 上限: 1000
# 反应: GALCTD, 下限: 0.0, 上限: 1000
# 反应: GALCTt2rpp, 下限: -999999.0, 上限: 1000
# 反应: GALCTtex, 下限: -999999.0, 上限: 1000
# 反应: GALURDH, 下限: -999999.0, 上限: 1000
# 反应: GALURt2rpp, 下限: -999999.0, 上限: 1000
# 反应: GALURtex, 下限: -999999.0, 上限: 1000
# 反应: GALUi, 下限: 0.0, 上限: 1000
# 反应: GAPD, 下限: -999999.0, 上限: 1000
# 反应: GARFT, 下限: -999999.0, 上限: 1000
# 反应: GART, 下限: 0.0, 上限: 1000
# 反应: GAt2pp, 下限: -999999.0, 上限: 1000
# 反应: GBDM, 下限: 0.0, 上限: 1000
# 反应: GCALDD, 下限: 0.0, 上限: 1000
# 反应: GCALDtabcpp, 下限: 0.0, 上限: 1000
# 反应: GDBTALDH, 下限: 0.0, 上限: 1000
# 反应: GDPDPK, 下限: 0.0, 上限: 1000
# 反应: GDPMANNDH, 下限: 0.0, 上限: 1000
# 反应: GDPTPDP, 下限: 0.0, 上限: 1000
# 反应: GF6PTA, 下限: 0.0, 上限: 1000
# 反应: GG15DAPAH, 下限: 0.0, 上限: 1000
# 反应: GG15DAPDxr, 下限: -999999.0, 上限: 1000
# 反应: GG15DAPO, 下限: 0.0, 上限: 1000
# 反应: GG15DAPS, 下限: 0.0, 上限: 1000
# 反应: GGDAPAH, 下限: 0.0, 上限: 1000
# 反应: GGDAPDxr, 下限: -999999.0, 上限: 1000
# 反应: GGDAPO, 下限: 0.0, 上限: 1000
# 反应: GGDAPS, 下限: 0.0, 上限: 1000
# 反应: GGGABADxr, 下限: -999999.0, 上限: 1000
# 反应: GGGABAH, 下限: 0.0, 上限: 1000
# 反应: GGPTRCO, 下限: 0.0, 上限: 1000
# 反应: GGPTRCS, 下限: 0.0, 上限: 1000
# 反应: GGSPMDO, 下限: 0.0, 上限: 1000
# 反应: GGSPMDS, 下限: 0.0, 上限: 1000
# 反应: GHMT2r, 下限: 0.0, 上限: 1000
# 反应: GK1, 下限: -999999.0, 上限: 1000
# 反应: GLBRAN3, 下限: 0.0, 上限: 1000
# 反应: GLCDpp, 下限: 0.0, 上限: 1000
# 反应: GLCNt2rpp, 下限: -999999.0, 上限: 1000
# 反应: GLCNtex, 下限: -999999.0, 上限: 1000
# 反应: GLCOAS, 下限: 0.0, 上限: 1000
# 反应: GLCOASYNT, 下限: 0.0, 上限: 1000
# 反应: GLCP3, 下限: 0.0, 上限: 1000
# 反应: GLCP4, 下限: 0.0, 上限: 1000
# 反应: GLCRD, 下限: 0.0, 上限: 1000
# 反应: GLCRt2rpp, 下限: -999999.0, 上限: 1000
# 反应: GLCRtex, 下限: -999999.0, 上限: 1000
# 反应: GLCS3_1, 下限: 0.0, 上限: 1000
# 反应: GLCURDH, 下限: -999999.0, 上限: 1000
# 反应: GLCURt2rpp, 下限: -999999.0, 上限: 1000
# 反应: GLCURtex, 下限: -999999.0, 上限: 1000
# 反应: GLCabcpp, 下限: 0.0, 上限: 1000
# 反应: GLCtex, 下限: -999999.0, 上限: 1000
# 反应: GLDBRAN3, 下限: 0.0, 上限: 1000
# 反应: GLGC, 下限: 0.0, 上限: 1000
# 反应: GLNS_copy1, 下限: 0.0, 上限: 1000
# 反应: GLNTRAT, 下限: 0.0, 上限: 1000
# 反应: GLNTRS, 下限: 0.0, 上限: 1000
# 反应: GLNtex, 下限: -999999.0, 上限: 1000
# 反应: GLU5K, 下限: 0.0, 上限: 1000
# 反应: GLUCYS_copy1, 下限: 0.0, 上限: 1000
# 反应: GLUDxi, 下限: -999999.0, 上限: 1000
# 反应: GLUDy, 下限: -999999.0, 上限: 1000
# 反应: GLUNpp, 下限: 0.0, 上限: 1000
# 反应: GLUPRT, 下限: 0.0, 上限: 1000
# 反应: GLUR, 下限: -999999.0, 上限: 1000
# 反应: GLUSy, 下限: 0.0, 上限: 1000
# 反应: GLUTARt2rpp, 下限: -999999.0, 上限: 1000
# 反应: GLUTARtex, 下限: -999999.0, 上限: 1000
# 反应: GLUTCOADHc, 下限: 0.0, 上限: 1000
# 反应: GLUTRR, 下限: 0.0, 上限: 1000
# 反应: GLUTRS, 下限: 0.0, 上限: 1000
# 反应: GLUabcpp, 下限: 0.0, 上限: 1000
# 反应: GLUt2rpp, 下限: 0.0, 上限: 1000
# 反应: GLUt4pp, 下限: 0.0, 上限: 1000
# 反应: GLUtex, 下限: -999999.0, 上限: 1000
# 反应: GLXCL, 下限: 0.0, 上限: 1000
# 反应: GLXO3r, 下限: 0.0, 上限: 1000
# 反应: GLYALDDr, 下限: -999999.0, 上限: 1000
# 反应: GLYALDtex, 下限: -999999.0, 上限: 1000
# 反应: GLYALDtpp, 下限: -999999.0, 上限: 1000
# 反应: GLYBACT1r, 下限: -999999.0, 上限: 1000
# 反应: GLYBCOAT, 下限: 0.0, 上限: 1000
# 反应: GLYBabcpp, 下限: 0.0, 上限: 1000
# 反应: GLYBt2pp, 下限: 0.0, 上限: 1000
# 反应: GLYBtex, 下限: -999999.0, 上限: 1000
# 反应: GLYBti4pp, 下限: 0.0, 上限: 1000
# 反应: GLYCAt2rpp, 下限: -999999.0, 上限: 1000
# 反应: GLYCAtex, 下限: -999999.0, 上限: 1000
# 反应: GLYCK, 下限: 0.0, 上限: 1000
# 反应: GLYCL, 下限: 0.0, 上限: 1000
# 反应: GLYCLTDx, 下限: 0.0, 上限: 1000
# 反应: GLYCLTDy, 下限: 0.0, 上限: 1000
# 反应: GLYCLTt2rpp, 下限: -999999.0, 上限: 1000
# 反应: GLYCLTt4pp, 下限: 0.0, 上限: 1000
# 反应: GLYCLTtex, 下限: -999999.0, 上限: 1000
# 反应: GLYCOLDHpp, 下限: 0.0, 上限: 1000
# 反应: GLYCOLtex, 下限: -999999.0, 上限: 1000
# 反应: GLYCTO1, 下限: 0.0, 上限: 1000
# 反应: GLYCtex, 下限: -999999.0, 上限: 1000
# 反应: GLYCtpp, 下限: -999999.0, 上限: 1000
# 反应: HPYRRx, 下限: -999999.0, 上限: 1000
# 反应: GLYGLNabcpp, 下限: 0.0, 上限: 1000
# 反应: GLYGLNtex, 下限: -999999.0, 上限: 1000
# 反应: GLYGLUabcpp, 下限: 0.0, 上限: 1000
# 反应: GLYGLUtex, 下限: -999999.0, 上限: 1000
# 反应: GLYGLYabcpp, 下限: 0.0, 上限: 1000
# 反应: GLYGLYtex, 下限: -999999.0, 上限: 1000
# 反应: GLYK, 下限: 0.0, 上限: 1000
# 反应: GLYMETabcpp, 下限: 0.0, 上限: 1000
# 反应: GLYMETtex, 下限: -999999.0, 上限: 1000
# 反应: GLYO1, 下限: 0.0, 上限: 1000
# 反应: GLYOX, 下限: 0.0, 上限: 1000
# 反应: GLYPHEabcpp, 下限: 0.0, 上限: 1000
# 反应: GLYPHEtex, 下限: -999999.0, 上限: 1000
# 反应: GLYSERabcpp, 下限: 0.0, 上限: 1000
# 反应: GLYSERtex, 下限: -999999.0, 上限: 1000
# 反应: GLYTRS, 下限: 0.0, 上限: 1000
# 反应: GLYabcpp, 下限: 0.0, 上限: 1000
# 反应: GLYt2pp, 下限: 0.0, 上限: 1000
# 反应: GLYt4pp, 下限: 0.0, 上限: 1000
# 反应: GLYtex, 下限: -999999.0, 上限: 1000
# 反应: GMAND, 下限: 0.0, 上限: 1000
# 反应: GMHEPAT, 下限: 0.0, 上限: 1000
# 反应: GMHEPK, 下限: 0.0, 上限: 1000
# 反应: GMHEPPA, 下限: 0.0, 上限: 1000
# 反应: GMPS2, 下限: 0.0, 上限: 1000
# 反应: GND, 下限: 0.0, 上限: 1000
# 反应: GNK, 下限: 0.0, 上限: 1000
# 反应: GNNUC, 下限: 0.0, 上限: 1000
# 反应: GPDDA2, 下限: 0.0, 上限: 1000
# 反应: GPDDA4, 下限: 0.0, 上限: 1000
# 反应: GPTNH, 下限: 0.0, 上限: 1000
# 反应: GRTT, 下限: 0.0, 上限: 1000
# 反应: GRXR, 下限: 0.0, 上限: 1000
# 反应: GTHOr, 下限: -999999.0, 上限: 1000
# 反应: GTHPi, 下限: 0.0, 上限: 1000
# 反应: GTHRDHpp, 下限: 0.0, 上限: 1000
# 反应: GTHRDabc2pp, 下限: 0.0, 上限: 1000
# 反应: GTHS, 下限: 0.0, 上限: 1000
# 反应: GTPCI, 下限: 0.0, 上限: 1000
# 反应: GTPCII2, 下限: 0.0, 上限: 1000
# 反应: GTPDPDP, 下限: 0.0, 上限: 1000
# 反应: GTPDPK, 下限: 0.0, 上限: 1000
# 反应: GTPHs, 下限: 0.0, 上限: 1000
# 反应: GTR1_kt, 下限: 0.0, 上限: 1000
# 反应: GTR2_kt, 下限: 0.0, 上限: 1000
# 反应: GUACYC, 下限: 0.0, 上限: 1000
# 反应: GUAD, 下限: 0.0, 上限: 1000
# 反应: GUAPRT, 下限: 0.0, 上限: 1000
# 反应: GUAt2pp, 下限: 0.0, 上限: 1000
# 反应: GUAtex, 下限: -999999.0, 上限: 1000
# 反应: GUDACabcpp, 下限: 0.0, 上限: 1000
# 反应: GUDACtex, 下限: -999999.0, 上限: 1000
# 反应: GUDBUTNAH, 下限: 0.0, 上限: 1000
# 反应: GUDPTNabcpp, 下限: 0.0, 上限: 1000
# 反应: GUDPTNtex, 下限: -999999.0, 上限: 1000
# 反应: H2CO3D, 下限: -999999.0, 上限: 1000
# 反应: H2CO3D2, 下限: -999999.0, 上限: 1000
# 反应: H2O2tex, 下限: -999999.0, 上限: 1000
# 反应: H2Otex, 下限: -999999.0, 上限: 1000
# 反应: H2Otpp, 下限: -999999.0, 上限: 1000
# 反应: H2SO, 下限: 0.0, 上限: 1000
# 反应: H2St1pp, 下限: 0.0, 上限: 1000
# 反应: H2Stex, 下限: -999999.0, 上限: 1000
# 反应: HACD10i, 下限: 0.0, 上限: 1000
# 反应: HACD11i, 下限: 0.0, 上限: 1000
# 反应: HACD12i, 下限: 0.0, 上限: 1000
# 反应: HACD13i, 下限: 0.0, 上限: 1000
# 反应: HACD14i, 下限: 0.0, 上限: 1000
# 反应: HACD15i, 下限: 0.0, 上限: 1000
# 反应: HACD16i, 下限: 0.0, 上限: 1000
# 反应: HACD17i, 下限: 0.0, 上限: 1000
# 反应: HACD18i, 下限: 0.0, 上限: 1000
# 反应: HACD19i, 下限: 0.0, 上限: 1000
# 反应: HACD1i, 下限: 0.0, 上限: 1000
# 反应: HACD20i, 下限: 0.0, 上限: 1000
# 反应: HACD21i, 下限: 0.0, 上限: 1000
# 反应: HACD22i, 下限: 0.0, 上限: 1000
# 反应: HACD23i, 下限: 0.0, 上限: 1000
# 反应: HACD24i, 下限: 0.0, 上限: 1000
# 反应: HACD25i, 下限: 0.0, 上限: 1000
# 反应: SBO3tex, 下限: -999999.0, 上限: 1000
# 反应: HACD26i, 下限: 0.0, 上限: 1000
# 反应: HACD27i, 下限: 0.0, 上限: 1000
# 反应: HACD28i, 下限: 0.0, 上限: 1000
# 反应: HACD29i, 下限: 0.0, 上限: 1000
# 反应: HACD2i, 下限: 0.0, 上限: 1000
# 反应: HACD30i, 下限: 0.0, 上限: 1000
# 反应: HACD31i, 下限: 0.0, 上限: 1000
# 反应: HACD32i, 下限: 0.0, 上限: 1000
# 反应: HACD33i, 下限: 0.0, 上限: 1000
# 反应: HACD3i, 下限: 0.0, 上限: 1000
# 反应: HACD4i, 下限: 0.0, 上限: 1000
# 反应: HACD5i, 下限: 0.0, 上限: 1000
# 反应: HACD6i, 下限: 0.0, 上限: 1000
# 反应: HACD7i, 下限: 0.0, 上限: 1000
# 反应: HACD8i, 下限: 0.0, 上限: 1000
# 反应: HACD9, 下限: -999999.0, 上限: 1000
# 反应: HVCD, 下限: -999999.0, 上限: 1000
# 反应: HADPCOADH3, 下限: -999999.0, 上限: 1000
# 反应: HAT40tex, 下限: -999999.0, 上限: 1000
# 反应: HAT40tpp, 下限: -999999.0, 上限: 1000
# 反应: HATBH, 下限: 0.0, 上限: 1000
# 反应: HBZOPT, 下限: 0.0, 上限: 1000
# 反应: HCO3E, 下限: -999999.0, 上限: 1000
# 反应: HCYSMT, 下限: 0.0, 上限: 1000
# 反应: HCYSMT2, 下限: 0.0, 上限: 1000
# 反应: HCYStabcpp, 下限: 0.0, 上限: 1000
# 反应: HCYStex, 下限: -999999.0, 上限: 1000
# 反应: HDCAtexi, 下限: 0.0, 上限: 1000
# 反应: HDCEAtexi, 下限: 0.0, 上限: 1000
# 反应: CTECOAI7, 下限: 0.0, 上限: 1000
# 反应: HEMEOS, 下限: 0.0, 上限: 1000
# 反应: HEPCT, 下限: 0.0, 上限: 1000
# 反应: HEPK1_kt, 下限: 0.0, 上限: 1000
# 反应: HEPK2_kt, 下限: 0.0, 上限: 1000
# 反应: HEPK3_kt, 下限: 0.0, 上限: 1000
# 反应: HEPT1_kt, 下限: 0.0, 上限: 1000
# 反应: HEPT2_kt, 下限: 0.0, 上限: 1000
# 反应: HEX1, 下限: 0.0, 上限: 1000
# 反应: HG2t3pp, 下限: 0.0, 上限: 1000
# 反应: HG2tex, 下限: -999999.0, 上限: 1000
# 反应: HG2tppi, 下限: 0.0, 上限: 1000
# 反应: HGENTISt2pp, 下限: 0.0, 上限: 1000
# 反应: HGENTIStex, 下限: -999999.0, 上限: 1000
# 反应: HGNTOR, 下限: 0.0, 上限: 1000
# 反应: HIBDkt, 下限: 0.0, 上限: 1000
# 反应: HISDr, 下限: 0.0, 上限: 1000
# 反应: HISGLYabcpp, 下限: 0.0, 上限: 1000
# 反应: HISGLYtex, 下限: -999999.0, 上限: 1000
# 反应: HISHISabcpp, 下限: 0.0, 上限: 1000
# 反应: HISHIStex, 下限: -999999.0, 上限: 1000
# 反应: HISTD, 下限: 0.0, 上限: 1000
# 反应: HISTP, 下限: 0.0, 上限: 1000
# 反应: HISTRS, 下限: 0.0, 上限: 1000
# 反应: HISabcpp, 下限: 0.0, 上限: 1000
# 反应: HISt2rpp, 下限: -999999.0, 上限: 1000
# 反应: HIStex, 下限: -999999.0, 上限: 1000
# 反应: HIUH_c, 下限: -999999.0, 上限: 1000
# 反应: HMBS, 下限: 0.0, 上限: 1000
# 反应: HMGL, 下限: 0.0, 上限: 1000
# 反应: HMPK1, 下限: 0.0, 上限: 1000
# 反应: HMSD, 下限: 0.0, 上限: 1000
# 反应: HMSD2, 下限: 0.0, 上限: 1000
# 反应: HMSH, 下限: 0.0, 上限: 1000
# 反应: HMSH2, 下限: 0.0, 上限: 1000
# 反应: HMSH3, 下限: 0.0, 上限: 1000
# 反应: HOMt2pp, 下限: 0.0, 上限: 1000
# 反应: HOMtex, 下限: -999999.0, 上限: 1000
# 反应: HOMtpp, 下限: 0.0, 上限: 1000
# 反应: HOPNTAL, 下限: 0.0, 上限: 1000
# 反应: HOPNTAL2, 下限: 0.0, 上限: 1000
# 反应: HOXG, 下限: 0.0, 上限: 1000
# 反应: HPAtexi, 下限: 0.0, 上限: 1000
# 反应: HPPK, 下限: 0.0, 上限: 1000
# 反应: HPYRI, 下限: -999999.0, 上限: 1000
# 反应: HPYRRy, 下限: 0.0, 上限: 1000
# 反应: HSDy, 下限: -999999.0, 上限: 1000
# 反应: HSERTA, 下限: -999999.0, 上限: 1000
# 反应: HSK, 下限: 0.0, 上限: 1000
# 反应: HSTPT, 下限: 0.0, 上限: 1000
# 反应: HXAND, 下限: 0.0, 上限: 1000
# 反应: HXANt2pp, 下限: 0.0, 上限: 1000
# 反应: HXAtex, 下限: 0.0, 上限: 1000
# 反应: HXPRT, 下限: 0.0, 上限: 1000
# 反应: HYGBDIAS, 下限: 0.0, 上限: 1000
# 反应: HYXNtex, 下限: -999999.0, 上限: 1000
# 反应: Htex, 下限: -999999.0, 上限: 1000
# 反应: I2FE2SR, 下限: 0.0, 上限: 1000
# 反应: I2FE2SS2fdx, 下限: 0.0, 上限: 1000
# 反应: I2FE2SSfdx, 下限: 0.0, 上限: 1000
# 反应: I2FE2ST, 下限: 0.0, 上限: 1000
# 反应: I4FE4SRfdx, 下限: 0.0, 上限: 1000
# 反应: I4FE4ST, 下限: 0.0, 上限: 1000
# 反应: ICDHyr, 下限: -999999.0, 上限: 1000
# 反应: ICITt4pp, 下限: 0.0, 上限: 1000
# 反应: ICITt_kt, 下限: -999999.0, 上限: 1000
# 反应: ICITtex, 下限: -999999.0, 上限: 1000
# 反应: ICL, 下限: 0.0, 上限: 1000
# 反应: ICYSDS, 下限: 0.0, 上限: 1000
# 反应: IG3PS, 下限: 0.0, 上限: 1000
# 反应: IGPDH, 下限: 0.0, 上限: 1000
# 反应: IGPS, 下限: 0.0, 上限: 1000
# 反应: ILEDHr_1, 下限: -999999.0, 上限: 1000
# 反应: ILETA, 下限: -999999.0, 上限: 1000
# 反应: ILETRS, 下限: 0.0, 上限: 1000
# 反应: ILEabcpp, 下限: 0.0, 上限: 1000
# 反应: ILEt2rpp, 下限: -999999.0, 上限: 1000
# 反应: ILEtex, 下限: -999999.0, 上限: 1000
# 反应: IMPC, 下限: -999999.0, 上限: 1000
# 反应: IMPD, 下限: 0.0, 上限: 1000
# 反应: IND3ACtex, 下限: -999999.0, 上限: 1000
# 反应: IND3ACtpp, 下限: 0.0, 上限: 1000
# 反应: INDOLEt5, 下限: 0.0, 上限: 1000
# 反应: INDOLEt6, 下限: 0.0, 上限: 1000
# 反应: INDOLEtex, 下限: -999999.0, 上限: 1000
# 反应: INDOLEtpp, 下限: 0.0, 上限: 1000
# 反应: INSH, 下限: 0.0, 上限: 1000
# 反应: INStex, 下限: -999999.0, 上限: 1000
# 反应: IPDDI, 下限: -999999.0, 上限: 1000
# 反应: IPDPS, 下限: 0.0, 上限: 1000
# 反应: IPMD, 下限: 0.0, 上限: 1000
# 反应: IPPMIa, 下限: -999999.0, 上限: 1000
# 反应: IPPMIb, 下限: -999999.0, 上限: 1000
# 反应: IPPS, 下限: 0.0, 上限: 1000
# 反应: ISETACabcpp, 下限: 0.0, 上限: 1000
# 反应: ISETACtex, 下限: -999999.0, 上限: 1000
# 反应: ISOAML, 下限: 0.0, 上限: 1000
# 反应: IVCS, 下限: 0.0, 上限: 1000
# 反应: IZPN, 下限: 0.0, 上限: 1000
# 反应: KARA1, 下限: -999999.0, 上限: 1000
# 反应: KARA2, 下限: -999999.0, 上限: 1000
# 反应: KAS14, 下限: 0.0, 上限: 1000
# 反应: KAS15, 下限: 0.0, 上限: 1000
# 反应: KAT1, 下限: 0.0, 上限: 1000
# 反应: KAT10, 下限: 0.0, 上限: 1000
# 反应: KAT11, 下限: 0.0, 上限: 1000
# 反应: KAT12, 下限: 0.0, 上限: 1000
# 反应: KAT13, 下限: 0.0, 上限: 1000
# 反应: KAT14, 下限: 0.0, 上限: 1000
# 反应: KAT15, 下限: 0.0, 上限: 1000
# 反应: KAT16, 下限: 0.0, 上限: 1000
# 反应: KAT17, 下限: 0.0, 上限: 1000
# 反应: KAT18, 下限: 0.0, 上限: 1000
# 反应: KAT19, 下限: 0.0, 上限: 1000
# 反应: ACACT11, 下限: 0.0, 上限: 1000
# 反应: KAT20, 下限: 0.0, 上限: 1000
# 反应: KAT21, 下限: 0.0, 上限: 1000
# 反应: KAT22, 下限: 0.0, 上限: 1000
# 反应: KAT23, 下限: 0.0, 上限: 1000
# 反应: KAT24, 下限: 0.0, 上限: 1000
# 反应: KAT25, 下限: 0.0, 上限: 1000
# 反应: KAT26, 下限: 0.0, 上限: 1000
# 反应: KAT27, 下限: 0.0, 上限: 1000
# 反应: KAT28, 下限: 0.0, 上限: 1000
# 反应: KAT29, 下限: 0.0, 上限: 1000
# 反应: ACACT8, 下限: 0.0, 上限: 1000
# 反应: KAT30, 下限: 0.0, 上限: 1000
# 反应: KAT31, 下限: 0.0, 上限: 1000
# 反应: KAT32, 下限: 0.0, 上限: 1000
# 反应: ACACT13, 下限: 0.0, 上限: 1000
# 反应: ACACT10, 下限: 0.0, 上限: 1000
# 反应: ACACT9, 下限: 0.0, 上限: 1000
# 反应: ACACT12, 下限: 0.0, 上限: 1000
# 反应: ACACT8r, 下限: 0.0, 上限: 1000
# 反应: VCACT, 下限: -999999.0, 上限: 1000
# 反应: KDOCT2, 下限: 0.0, 上限: 1000
# 反应: KDOPP, 下限: 0.0, 上限: 1000
# 反应: KDOPS, 下限: 0.0, 上限: 1000
# 反应: Kabcpp, 下限: 0.0, 上限: 1000
# 反应: Kt2pp, 下限: 0.0, 上限: 1000
# 反应: Kt3pp, 下限: 0.0, 上限: 1000
# 反应: Ktex, 下限: -999999.0, 上限: 1000
# 反应: LALALGLUtex, 下限: -999999.0, 上限: 1000
# 反应: LALGP, 下限: 0.0, 上限: 1000
# 反应: LCADi, 下限: 0.0, 上限: 1000
# 反应: LCTSt3ipp, 下限: 0.0, 上限: 1000
# 反应: LDH_D, 下限: -999999.0, 上限: 1000
# 反应: LDH_D2, 下限: 0.0, 上限: 1000
# 反应: LLEUDr, 下限: -999999.0, 上限: 1000
# 反应: LEULEUabcpp, 下限: 0.0, 上限: 1000
# 反应: LEULEUtex, 下限: -999999.0, 上限: 1000
# 反应: LEUTA, 下限: -999999.0, 上限: 1000
# 反应: LEUTRS, 下限: 0.0, 上限: 1000
# 反应: LEUabcpp, 下限: 0.0, 上限: 1000
# 反应: LEUt2rpp, 下限: -999999.0, 上限: 1000
# 反应: LEUtex, 下限: -999999.0, 上限: 1000
# 反应: LGTHL, 下限: 0.0, 上限: 1000
# 反应: LIPAH, 下限: 0.0, 上限: 1000
# 反应: LIPOCT, 下限: 0.0, 上限: 1000
# 反应: LIPOS, 下限: 0.0, 上限: 1000
# 反应: LNLCtexi, 下限: 0.0, 上限: 1000
# 反应: LPADSS2_1, 下限: 0.0, 上限: 1000
# 反应: LPCOXc, 下限: 0.0, 上限: 1000
# 反应: LPLIPAL1E160pp, 下限: 0.0, 上限: 1000
# 反应: LPLIPAL1E161pp, 下限: 0.0, 上限: 1000
# 反应: LPLIPAL1E180pp, 下限: 0.0, 上限: 1000
# 反应: LPLIPAL1E181d11pp, 下限: 0.0, 上限: 1000
# 反应: LPLIPAL1G160pp, 下限: 0.0, 上限: 1000
# 反应: LPLIPAL1G161pp, 下限: 0.0, 上限: 1000
# 反应: LPLIPAL1G180pp, 下限: 0.0, 上限: 1000
# 反应: LPLIPAL1G181d11pp, 下限: 0.0, 上限: 1000
# 反应: LPSALAT, 下限: 0.0, 上限: 1000
# 反应: LPSGTR1_kt, 下限: 0.0, 上限: 1000
# 反应: LPSGTR2_kt, 下限: 0.0, 上限: 1000
# 反应: LPSGTR3_kt, 下限: 0.0, 上限: 1000
# 反应: LPSGTR4_kt, 下限: 0.0, 上限: 1000
# 反应: LSERDHr, 下限: -999999.0, 上限: 1000
# 反应: LTDCL, 下限: 0.0, 上限: 1000
# 反应: LYSDC, 下限: 0.0, 上限: 1000
# 反应: LYSMO, 下限: 0.0, 上限: 1000
# 反应: LYSRC, 下限: -999999.0, 上限: 1000
# 反应: LYSTRS, 下限: 0.0, 上限: 1000
# 反应: LYSabcpp, 下限: 0.0, 上限: 1000
# 反应: LYStex, 下限: -999999.0, 上限: 1000
# 反应: L_LACD2, 下限: 0.0, 上限: 1000
# 反应: L_LACt2rpp, 下限: -999999.0, 上限: 1000
# 反应: L_LACtex, 下限: -999999.0, 上限: 1000
# 反应: MACACI, 下限: 0.0, 上限: 1000
# 反应: MACCOAT, 下限: 0.0, 上限: 1000
# 反应: MACPD, 下限: 0.0, 上限: 1000
# 反应: MAGLIPA160ex, 下限: 0.0, 上限: 1000
# 反应: MAGLIPA180ex, 下限: 0.0, 上限: 1000
# 反应: MAGLIPA181d9ex, 下限: 0.0, 上限: 1000
# 反应: MAGLIPA182d9d12ex, 下限: 0.0, 上限: 1000
# 反应: MAK, 下限: 0.0, 上限: 1000
# 反应: MALCOAMT, 下限: 0.0, 上限: 1000
# 反应: MALDt2_2pp, 下限: 0.0, 上限: 1000
# 反应: MALDtex, 下限: -999999.0, 上限: 1000
# 反应: MALEI, 下限: -999999.0, 上限: 1000
# 反应: MALS, 下限: 0.0, 上限: 1000
# 反应: MALTT, 下限: 0.0, 上限: 1000
# 反应: MALt2_2pp, 下限: 0.0, 上限: 1000
# 反应: MALtex, 下限: -999999.0, 上限: 1000
# 反应: MAN1PT2, 下限: 0.0, 上限: 1000
# 反应: MAN6PI, 下限: -999999.0, 上限: 1000
# 反应: MANE, 下限: -999999.0, 上限: 1000
# 反应: MANabcpp, 下限: 0.0, 上限: 1000
# 反应: MANtex, 下限: -999999.0, 上限: 1000
# 反应: MBCOAi, 下限: 0.0, 上限: 1000
# 反应: MCBTFR1, 下限: 0.0, 上限: 1000
# 反应: MCBTFR2, 下限: 0.0, 上限: 1000
# 反应: MCBTFUexs, 下限: 0.0, 上限: 1000
# 反应: MCBTFabcpp, 下限: 0.0, 上限: 1000
# 反应: MCBTFtex, 下限: 0.0, 上限: 1000
# 反应: MCBTFtonex, 下限: 0.0, 上限: 1000
# 反应: MCBTFtpp, 下限: 0.0, 上限: 1000
# 反应: MCCC, 下限: 0.0, 上限: 1000
# 反应: MCITD, 下限: 0.0, 上限: 1000
# 反应: MCITL2, 下限: -999999.0, 上限: 1000
# 反应: MCITS, 下限: 0.0, 上限: 1000
# 反应: MCOATA, 下限: -999999.0, 上限: 1000
# 反应: MCSNAH, 下限: 0.0, 上限: 1000
# 反应: MCSNtex, 下限: -999999.0, 上限: 1000
# 反应: MCSNtpp, 下限: 0.0, 上限: 1000
# 反应: MCTP1App, 下限: 0.0, 上限: 1000
# 反应: MCTP1Bpp, 下限: 0.0, 上限: 1000
# 反应: MCTP2App, 下限: 0.0, 上限: 1000
# 反应: MDDCP1pp, 下限: 0.0, 上限: 1000
# 反应: MDDCP2pp, 下限: 0.0, 上限: 1000
# 反应: MDDCP3pp, 下限: 0.0, 上限: 1000
# 反应: MDDCP4pp, 下限: 0.0, 上限: 1000
# 反应: MDDCP5pp, 下限: 0.0, 上限: 1000
# 反应: MDDEP1pp, 下限: 0.0, 上限: 1000
# 反应: MDDEP2pp, 下限: 0.0, 上限: 1000
# 反应: MDDEP3pp, 下限: 0.0, 上限: 1000
# 反应: MDDEP4pp, 下限: 0.0, 上限: 1000
# 反应: MDH, 下限: -999999.0, 上限: 1000
# 反应: MDH2, 下限: 0.0, 上限: 1000
# 反应: MDNTHAep, 下限: 0.0, 上限: 1000
# 反应: ME2, 下限: 0.0, 上限: 1000
# 反应: MECDPDH5, 下限: 0.0, 上限: 1000
# 反应: MECDPS_copy1, 下限: 0.0, 上限: 1000
# 反应: MELIBt3ipp, 下限: 0.0, 上限: 1000
# 反应: MEOHtex, 下限: -999999.0, 上限: 1000
# 反应: MEOHtrpp, 下限: -999999.0, 上限: 1000
# 反应: MEPCT, 下限: 0.0, 上限: 1000
# 反应: METAT, 下限: 0.0, 上限: 1000
# 反应: METDabcpp, 下限: 0.0, 上限: 1000
# 反应: METGL, 下限: 0.0, 上限: 1000
# 反应: METOX1s, 下限: 0.0, 上限: 1000
# 反应: METOX2s, 下限: 0.0, 上限: 1000
# 反应: METS, 下限: 0.0, 上限: 1000
# 反应: METSOXR1, 下限: 0.0, 上限: 1000
# 反应: METSOXR2, 下限: 0.0, 上限: 1000
# 反应: METTRS, 下限: 0.0, 上限: 1000
# 反应: METabcpp, 下限: 0.0, 上限: 1000
# 反应: METtex, 下限: -999999.0, 上限: 1000
# 反应: MG2tex, 下限: -999999.0, 上限: 1000
# 反应: MG2tpp, 下限: 0.0, 上限: 1000
# 反应: MG2uabcpp, 下限: 0.0, 上限: 1000
# 反应: MGCH, 下限: 0.0, 上限: 1000
# 反应: MI1PP, 下限: 0.0, 上限: 1000
# 反应: MICITDr, 下限: -999999.0, 上限: 1000
# 反应: MLDCP1App, 下限: 0.0, 上限: 1000
# 反应: MLDCP1Bpp, 下限: 0.0, 上限: 1000
# 反应: MLDCP2App, 下限: 0.0, 上限: 1000
# 反应: MLDCP2Bpp, 下限: 0.0, 上限: 1000
# 反应: MLDCP3App, 下限: 0.0, 上限: 1000
# 反应: MLDEP1pp, 下限: 0.0, 上限: 1000
# 反应: MLDEP2pp, 下限: 0.0, 上限: 1000
# 反应: MLTGY1pp, 下限: 0.0, 上限: 1000
# 反应: MLTGY2pp, 下限: 0.0, 上限: 1000
# 反应: MLTGY3pp, 下限: 0.0, 上限: 1000
# 反应: MLTGY4pp, 下限: 0.0, 上限: 1000
# 反应: MMETt2pp, 下限: 0.0, 上限: 1000
# 反应: MMETtex, 下限: -999999.0, 上限: 1000
# 反应: MMSAD3, 下限: 0.0, 上限: 1000
# 反应: MMTSAO, 下限: 0.0, 上限: 1000
# 反应: MN2t3pp, 下限: 0.0, 上限: 1000
# 反应: MNabc_1, 下限: 0.0, 上限: 1000
# 反应: MNtex, 下限: -999999.0, 上限: 1000
# 反应: MOADSUx, 下限: 0.0, 上限: 1000
# 反应: MOAT2_kt, 下限: 0.0, 上限: 1000
# 反应: MOAT_kt, 下限: 0.0, 上限: 1000
# 反应: MOBDabcpp, 下限: 0.0, 上限: 1000
# 反应: MOBDtex, 下限: -999999.0, 上限: 1000
# 反应: MOCOS, 下限: 0.0, 上限: 1000
# 反应: MOGDS, 下限: 0.0, 上限: 1000
# 反应: MOHMT, 下限: 0.0, 上限: 1000
# 反应: MOTH1, 下限: 0.0, 上限: 1000
# 反应: MOTS1, 下限: 0.0, 上限: 1000
# 反应: MPTAT, 下限: 0.0, 上限: 1000
# 反应: MPTG, 下限: 0.0, 上限: 1000
# 反应: MPTG2, 下限: 0.0, 上限: 1000
# 反应: MPTS, 下限: 0.0, 上限: 1000
# 反应: MPTSS, 下限: 0.0, 上限: 1000
# 反应: MSO3abcpp, 下限: 0.0, 上限: 1000
# 反应: MSO3tex, 下限: -999999.0, 上限: 1000
# 反应: MSULR, 下限: -999999.0, 上限: 1000
# 反应: MTHFC, 下限: -999999.0, 上限: 1000
# 反应: MTHFD, 下限: -999999.0, 上限: 1000
# 反应: MTHFR2, 下限: 0.0, 上限: 1000
# 反应: MTI, 下限: -999999.0, 上限: 1000
# 反应: MTOLDOX, 下限: 0.0, 上限: 1000
# 反应: MTRI, 下限: -999999.0, 上限: 1000
# 反应: MUCCYCI, 下限: -999999.0, 上限: 1000
# 反应: MUCCY_kt, 下限: 0.0, 上限: 1000
# 反应: MUCLI, 下限: -999999.0, 上限: 1000
# 反应: MXMO, 下限: 0.0, 上限: 1000
# 反应: MXYLt5, 下限: 0.0, 上限: 1000
# 反应: MXYLt6, 下限: 0.0, 上限: 1000
# 反应: M_XYLtpp, 下限: -999999.0, 上限: 1000
# 反应: M_Xylt1, 下限: -999999.0, 上限: 1000
# 反应: NACHY, 下限: 0.0, 上限: 1000
# 反应: NACODA, 下限: 0.0, 上限: 1000
# 反应: NACt1pp, 下限: -999999.0, 上限: 1000
# 反应: NACtex, 下限: -999999.0, 上限: 1000
# 反应: NADDP, 下限: 0.0, 上限: 1000
# 反应: NADH16pp, 下限: 0.0, 上限: 1000
# 反应: NADH5, 下限: 0.0, 上限: 1000
# 反应: NADHPO, 下限: 0.0, 上限: 1000
# 反应: NADK, 下限: 0.0, 上限: 1000
# 反应: NADN, 下限: 0.0, 上限: 1000
# 反应: NADPHQR2, 下限: 0.0, 上限: 1000
# 反应: NADS1, 下限: 0.0, 上限: 1000
# 反应: NADTRHD, 下限: 0.0, 上限: 1000
# 反应: NAMNPP, 下限: 0.0, 上限: 1000
# 反应: NAt3_1p5pp, 下限: 0.0, 上限: 1000
# 反应: NAt3pp_copy1, 下限: -999999.0, 上限: 1000
# 反应: NAt3_2pp, 下限: 0.0, 上限: 1000
# 反应: NAt3pp_copy2, 下限: 0.0, 上限: 1000
# 反应: NAtex, 下限: -999999.0, 上限: 1000
# 反应: NBAHH_ir, 下限: 0.0, 上限: 1000
# 反应: NCBMPTSabcpp, 下限: 0.0, 上限: 1000
# 反应: NCBMPTStex, 下限: -999999.0, 上限: 1000
# 反应: NDPK1, 下限: -999999.0, 上限: 1000
# 反应: NDPK2, 下限: -999999.0, 上限: 1000
# 反应: NDPK3, 下限: -999999.0, 上限: 1000
# 反应: NDPK4, 下限: -999999.0, 上限: 1000
# 反应: NDPK5, 下限: -999999.0, 上限: 1000
# 反应: NDPK6, 下限: -999999.0, 上限: 1000
# 反应: NDPK7, 下限: -999999.0, 上限: 1000
# 反应: NDPK8, 下限: -999999.0, 上限: 1000
# 反应: NFMLDF, 下限: 0.0, 上限: 1000
# 反应: NFORGLUAH2, 下限: 0.0, 上限: 1000
# 反应: NH4t3pp, 下限: 0.0, 上限: 1000
# 反应: NH4tex, 下限: -999999.0, 上限: 1000
# ...
# 反应: ADOCBLabcpp, 下限: 0.0, 上限: 1000
# 反应: ADOCBLtonex, 下限: 0.0, 上限: 1000
# 反应: ADPRDP, 下限: 0.0, 上限: 1000
# 反应: ADPT, 下限: 0.0, 上限: 1000
# 反应: ADSELK, 下限: 0.0, 上限: 1000
# 反应: ADSELR, 下限: 0.0, 上限: 1000
# 反应: ADSELR2, 下限: 0.0, 上限: 1000
# 反应: ADSK, 下限: 0.0, 上限: 1000
# 反应: ADSL1r, 下限: -999999.0, 上限: 1000
# 反应: ADSL2r, 下限: -999999.0, 上限: 1000
# 反应: ADSS, 下限: 0.0, 上限: 1000
# 反应: AEPabcpp, 下限: 0.0, 上限: 1000
# 反应: AEPTA, 下限: -999999.0, 上限: 1000
# 反应: AEPtex, 下限: -999999.0, 上限: 1000
# 反应: AGM3PA, 下限: 0.0, 上限: 1000
# 反应: AGM3PApp, 下限: 0.0, 上限: 1000
# 反应: AGM3PH, 下限: 0.0, 上限: 1000
# 反应: AGM3Pt2pp, 下限: 0.0, 上限: 1000
# 反应: AGM4PA, 下限: 0.0, 上限: 1000
# 反应: AGM4PApp, 下限: 0.0, 上限: 1000
# 反应: AGM4PCP, 下限: 0.0, 上限: 1000
# 反应: AGM4PCPpp, 下限: 0.0, 上限: 1000
# 反应: AGM4PH, 下限: 0.0, 上限: 1000
# 反应: AGM4Pt2pp, 下限: 0.0, 上限: 1000
# 反应: AGMDA, 下限: 0.0, 上限: 1000
# 反应: AGMH, 下限: 0.0, 上限: 1000
# 反应: AGMHE, 下限: 0.0, 上限: 1000
# 反应: AGMT, 下限: 0.0, 上限: 1000
# 反应: AGMabcpp, 下限: 0.0, 上限: 1000
# 反应: AGMt2pp, 下限: 0.0, 上限: 1000
# 反应: AGMtex, 下限: -999999.0, 上限: 1000
# 反应: AGPAT120, 下限: 0.0, 上限: 1000
# 反应: AGPAT140, 下限: 0.0, 上限: 1000
# 反应: AGPAT141, 下限: 0.0, 上限: 1000
# 反应: AGPAT160, 下限: 0.0, 上限: 1000
# 反应: AGPAT161, 下限: 0.0, 上限: 1000
# 反应: AGPAT180, 下限: 0.0, 上限: 1000
# 反应: AGPAT181, 下限: 0.0, 上限: 1000
# 反应: AGPR, 下限: -999999.0, 上限: 1000
# 反应: AGt3, 下限: 0.0, 上限: 1000
# 反应: AGtex, 下限: -999999.0, 上限: 1000
# 反应: AGtpp, 下限: 0.0, 上限: 1000
# 反应: AHCi, 下限: -999999.0, 上限: 1000
# 反应: AHSERL2, 下限: 0.0, 上限: 1000
# 反应: AICART, 下限: -999999.0, 上限: 1000
# 反应: AIRC2, 下限: 0.0, 上限: 1000
# 反应: AIRC3, 下限: -999999.0, 上限: 1000
# 反应: AKGDH, 下限: 0.0, 上限: 1000
# 反应: AKGDa, 下限: -999999.0, 上限: 1000
# 反应: AKGDb_copy1, 下限: -999999.0, 上限: 1000
# 反应: AKGt2rpp, 下限: -999999.0, 上限: 1000
# 反应: AKGtex, 下限: -999999.0, 上限: 1000
# 反应: ALAALAabcpp, 下限: 0.0, 上限: 1000
# 反应: ALAALAr, 下限: -999999.0, 上限: 1000
# 反应: ALAALAtex, 下限: -999999.0, 上限: 1000
# 反应: ALAGLUabcpp, 下限: 0.0, 上限: 1000
# 反应: ALAHISabcpp, 下限: 0.0, 上限: 1000
# 反应: ALAHIStex, 下限: -999999.0, 上限: 1000
# 反应: ALALEUabcpp, 下限: 0.0, 上限: 1000
# 反应: ALALEUtex, 下限: -999999.0, 上限: 1000
# 反应: ALAR, 下限: -999999.0, 上限: 1000
# 反应: ALATA_L, 下限: -999999.0, 上限: 1000
# 反应: ALATHRabcpp, 下限: 0.0, 上限: 1000
# 反应: ALATHRtex, 下限: -999999.0, 上限: 1000
# 反应: ALATRPabcpp, 下限: 0.0, 上限: 1000
# 反应: ALATRPtex, 下限: -999999.0, 上限: 1000
# 反应: ALATRS, 下限: 0.0, 上限: 1000
# 反应: ALAabcpp, 下限: 0.0, 上限: 1000
# 反应: ALAt2pp, 下限: 0.0, 上限: 1000
# 反应: ALAt4pp, 下限: 0.0, 上限: 1000
# 反应: ALAtex, 下限: -999999.0, 上限: 1000
# 反应: ALCD19, 下限: -999999.0, 上限: 1000
# 反应: ALCD2x, 下限: -999999.0, 上限: 1000
# 反应: ALCDpp, 下限: 0.0, 上限: 1000
# 反应: ALDD1, 下限: 0.0, 上限: 1000
# 反应: ALDD19xr, 下限: 0.0, 上限: 1000
# 反应: ALDD20x, 下限: 0.0, 上限: 1000
# 反应: ALDD2x, 下限: 0.0, 上限: 1000
# 反应: ALDD31, 下限: 0.0, 上限: 1000
# 反应: ALDD3y_copy1, 下限: 0.0, 上限: 1000
# 反应: ALDD4, 下限: 0.0, 上限: 1000
# 反应: ALGAC1, 下限: 0.0, 上限: 1000
# 反应: ALGAC2, 下限: 0.0, 上限: 1000
# 反应: ALGAC3, 下限: 0.0, 上限: 1000
# 反应: ALGAC4, 下限: 0.0, 上限: 1000
# 反应: ALGAC5, 下限: 0.0, 上限: 1000
# 反应: ALGE1, 下限: -999999.0, 上限: 1000
# 反应: ALGE2, 下限: -999999.0, 上限: 1000
# 反应: ALGE3, 下限: -999999.0, 上限: 1000
# 反应: ALGE4, 下限: -999999.0, 上限: 1000
# 反应: ALGE5, 下限: -999999.0, 上限: 1000
# 反应: ALGE6, 下限: -999999.0, 上限: 1000
# 反应: ALGE7, 下限: -999999.0, 上限: 1000
# 反应: ALGE8, 下限: -999999.0, 上限: 1000
# 反应: ASPTA, 下限: -999999.0, 上限: 1000
# 反应: ASPTRS, 下限: 0.0, 上限: 1000
# 反应: ASPabcpp, 下限: 0.0, 上限: 1000
# 反应: ASPt2pp, 下限: 0.0, 上限: 1000
# 反应: ASPtex, 下限: -999999.0, 上限: 1000
# 反应: ASR, 下限: 0.0, 上限: 1000
# 反应: AST, 下限: 0.0, 上限: 1000
# 反应: ATHRDHr, 下限: -999999.0, 上限: 1000
# 反应: ATPHs, 下限: 0.0, 上限: 1000
# 反应: ATPM, 下限: 0.92, 上限: 1000
# 反应: ATPPRT, 下限: 0.0, 上限: 1000
# 反应: ATPS4rpp, 下限: -999999.0, 上限: 1000
# 反应: BACCL, 下限: 0.0, 上限: 1000
# 反应: BALAALAabcpp, 下限: 0.0, 上限: 1000
# 反应: BALAALAtex, 下限: -999999.0, 上限: 1000
# 反应: BALABALAabcpp, 下限: 0.0, 上限: 1000
# 反应: BALABALAtex, 下限: -999999.0, 上限: 1000
# 反应: BALAGLYabcpp, 下限: 0.0, 上限: 1000
# 反应: BALAGLYtex, 下限: -999999.0, 上限: 1000
# 反应: BALALEUabcpp, 下限: 0.0, 上限: 1000
# 反应: BALALEUtex, 下限: -999999.0, 上限: 1000
# 反应: BALAMDAH, 下限: 0.0, 上限: 1000
# 反应: BALAt2pp, 下限: 0.0, 上限: 1000
# 反应: BALAtex, 下限: -999999.0, 上限: 1000
# 反应: BDH, 下限: -999999.0, 上限: 1000
# 反应: BETALDHx, 下限: 0.0, 上限: 1000
# 反应: BETALDHy, 下限: 0.0, 上限: 1000
# 反应: BGLApp, 下限: 0.0, 上限: 1000
# 反应: BHBtpp, 下限: 0.0, 上限: 1000
# 反应: BILIVERDtex, 下限: -999999.0, 上限: 1000
# 反应: BILIVERDtpp, 下限: -999999.0, 上限: 1000
# 反应: BLAMDabcpp, 下限: 0.0, 上限: 1000
# 反应: BLAMDtex, 下限: -999999.0, 上限: 1000
# 反应: BLUB, 下限: 0.0, 上限: 1000
# 反应: BMOCOS, 下限: 0.0, 上限: 1000
# 反应: BMOGDS1, 下限: 0.0, 上限: 1000
# 反应: BMOGDS2, 下限: 0.0, 上限: 1000
# 反应: BPNT, 下限: 0.0, 上限: 1000
# 反应: BTDD_RR, 下限: -999999.0, 上限: 1000
# 反应: BTDDtex, 下限: -999999.0, 上限: 1000
# 反应: BTDDtpp, 下限: -999999.0, 上限: 1000
# 反应: BTNt2ipp, 下限: 0.0, 上限: 1000
# 反应: BTNtex, 下限: -999999.0, 上限: 1000
# 反应: BTS5, 下限: 0.0, 上限: 1000
# 反应: BUP, 下限: 0.0, 上限: 1000
# 反应: BUTSO3abcpp, 下限: 0.0, 上限: 1000
# 反应: BUTSO3tex, 下限: -999999.0, 上限: 1000
# 反应: BWCOGDS1, 下限: 0.0, 上限: 1000
# 反应: BWCOGDS2, 下限: 0.0, 上限: 1000
# 反应: BWCOS, 下限: 0.0, 上限: 1000
# 反应: BZ12DOX, 下限: 0.0, 上限: 1000
# 反应: BZALDH, 下限: 0.0, 上限: 1000
# 反应: DGUDBUTNtex, 下限: -999999.0, 上限: 1000
# 反应: CHOLt4ipp, 下限: 0.0, 上限: 1000
# 反应: CHORM, 下限: 0.0, 上限: 1000
# 反应: CHORS, 下限: 0.0, 上限: 1000
# 反应: CHORt2rpp, 下限: -999999.0, 上限: 1000
# 反应: CHORtex, 下限: -999999.0, 上限: 1000
# 反应: CHRPL, 下限: 0.0, 上限: 1000
# 反应: CINNMCOAH, 下限: 0.0, 上限: 1000
# 反应: CINNMtex, 下限: -999999.0, 上限: 1000
# 反应: CINNMtpp, 下限: -999999.0, 上限: 1000
# 反应: CITt4pp_1, 下限: 0.0, 上限: 1000
# 反应: CITt_kt, 下限: -999999.0, 上限: 1000
# 反应: CITtex, 下限: -999999.0, 上限: 1000
# 反应: CLPNH120pp, 下限: 0.0, 上限: 1000
# 反应: CLPNH140pp, 下限: 0.0, 上限: 1000
# 反应: CLPNH141pp, 下限: 0.0, 上限: 1000
# 反应: CLPNH160pp, 下限: 0.0, 上限: 1000
# 反应: CLPNH161pp, 下限: 0.0, 上限: 1000
# 反应: CLPNH180pp, 下限: 0.0, 上限: 1000
# 反应: CLPNH181pp, 下限: 0.0, 上限: 1000
# 反应: CLPNS120pp, 下限: -999999.0, 上限: 1000
# 反应: CLPNS140pp, 下限: -999999.0, 上限: 1000
# 反应: CLPNS141pp, 下限: -999999.0, 上限: 1000
# 反应: CLPNS160pp, 下限: -999999.0, 上限: 1000
# 反应: CLPNS161pp, 下限: -999999.0, 上限: 1000
# 反应: CLPNS180pp, 下限: -999999.0, 上限: 1000
# 反应: CLPNS181pp, 下限: -999999.0, 上限: 1000
# 反应: CLt3_2pp, 下限: 0.0, 上限: 1000
# 反应: CLtex, 下限: -999999.0, 上限: 1000
# 反应: CMCBTFR1, 下限: 0.0, 上限: 1000
# 反应: CMCBTFR2, 下限: 0.0, 上限: 1000
# 反应: CMCBTFabcpp, 下限: 0.0, 上限: 1000
# 反应: CMCBTFexs, 下限: 0.0, 上限: 1000
# 反应: CMCBTFtex, 下限: 0.0, 上限: 1000
# 反应: CMCBTFtonex, 下限: 0.0, 上限: 1000
# 反应: CMCBTFtpp, 下限: 0.0, 上限: 1000
# 反应: CYTOM, 下限: -999999.0, 上限: 1000
# 反应: CMt2ex, 下限: 0.0, 上限: 1000
# 反应: CMt2ppi, 下限: 0.0, 上限: 1000
# 反应: CMtex, 下限: -999999.0, 上限: 1000
# 反应: CMtexabc, 下限: 0.0, 上限: 1000
# 反应: CMtpp, 下限: 0.0, 上限: 1000
# 反应: CO2tex, 下限: -999999.0, 上限: 1000
# 反应: CO2tpp, 下限: -999999.0, 上限: 1000
# 反应: COALCDH, 下限: 0.0, 上限: 1000
# 反应: COALDDH, 下限: 0.0, 上限: 1000
# 反应: COBALT2t3pp, 下限: 0.0, 上限: 1000
# 反应: COBALT2tex, 下限: -999999.0, 上限: 1000
# 反应: COBALT2tpp, 下限: 0.0, 上限: 1000
# 反应: COBALTt4pp, 下限: 0.0, 上限: 1000
# 反应: R05217_nad, 下限: 0.0, 上限: 1000
# 反应: COCHL, 下限: 0.0, 上限: 1000
# 反应: COCOAHA, 下限: 0.0, 上限: 1000
# 反应: COLIPAabcpp_kt, 下限: 0.0, 上限: 1000
# 反应: CONFRLtex, 下限: -999999.0, 上限: 1000
# 反应: CONFRLtpp, 下限: -999999.0, 上限: 1000
# 反应: COt_1, 下限: -999999.0, 上限: 1000
# 反应: Cotpp, 下限: -999999.0, 上限: 1000
# 反应: CPH4S, 下限: 0.0, 上限: 1000
# 反应: CPMPS, 下限: 0.0, 上限: 1000
# 反应: CPPPGO, 下限: 0.0, 上限: 1000
# 反应: DAAD11, 下限: 0.0, 上限: 1000
# 反应: DAAD12, 下限: 0.0, 上限: 1000
# 反应: DAAD2, 下限: 0.0, 上限: 1000
# 反应: DAAD3, 下限: 0.0, 上限: 1000
# 反应: DAAD4, 下限: 0.0, 上限: 1000
# 反应: DAAD5, 下限: 0.0, 上限: 1000
# 反应: PHET, 下限: 0.0, 上限: 1000
# 反应: DAAD7, 下限: 0.0, 上限: 1000
# 反应: DAAD8, 下限: 0.0, 上限: 1000
# 反应: DABAAT2, 下限: -999999.0, 上限: 1000
# 反应: DADA, 下限: 0.0, 上限: 1000
# 反应: DADK, 下限: -999999.0, 上限: 1000
# 反应: DAGK120, 下限: 0.0, 上限: 1000
# 反应: DAGK140, 下限: 0.0, 上限: 1000
# 反应: DAGK141, 下限: 0.0, 上限: 1000
# 反应: DAGK160, 下限: 0.0, 上限: 1000
# 反应: DAGK161, 下限: 0.0, 上限: 1000
# 反应: DAGK180, 下限: 0.0, 上限: 1000
# 反应: DAGK181, 下限: 0.0, 上限: 1000
# 反应: DAGLIPA160ex, 下限: 0.0, 上限: 1000
# 反应: DAGLIPA180ex, 下限: 0.0, 上限: 1000
# 反应: DAGLIPA181d9ex, 下限: 0.0, 上限: 1000
# 反应: DAGLIPA182d9d12ex, 下限: 0.0, 上限: 1000
# 反应: DALAALAD, 下限: 0.0, 上限: 1000
# 反应: DALADALAD, 下限: 0.0, 上限: 1000
# 反应: DALAGLYD, 下限: 0.0, 上限: 1000
# 反应: DALALEUD, 下限: 0.0, 上限: 1000
# 反应: DALAabcpp, 下限: 0.0, 上限: 1000
# 反应: DALAt2pp, 下限: 0.0, 上限: 1000
# 反应: DALAtex, 下限: -999999.0, 上限: 1000
# 反应: DAPAT, 下限: 0.0, 上限: 1000
# 反应: DAPDC, 下限: 0.0, 上限: 1000
# 反应: DAPE, 下限: -999999.0, 上限: 1000
# 反应: DAPabcpp, 下限: 0.0, 上限: 1000
# 反应: DAPtex, 下限: -999999.0, 上限: 1000
# 反应: DARGabcpp, 下限: 0.0, 上限: 1000
# 反应: DARGtex, 下限: -999999.0, 上限: 1000
# 反应: DASNabcpp, 下限: 0.0, 上限: 1000
# 反应: DASNtex, 下限: -999999.0, 上限: 1000
# 反应: DASYN120, 下限: 0.0, 上限: 1000
# 反应: DASYN140, 下限: 0.0, 上限: 1000
# 反应: DASYN141, 下限: 0.0, 上限: 1000
# 反应: DASYN160, 下限: 0.0, 上限: 1000
# 反应: DASYN161, 下限: 0.0, 上限: 1000
# 反应: DASYN180, 下限: 0.0, 上限: 1000
# 反应: DASYN181, 下限: 0.0, 上限: 1000
# 反应: DATPHs, 下限: 0.0, 上限: 1000
# 反应: DB4PS, 下限: 0.0, 上限: 1000
# 反应: DBTS, 下限: 0.0, 上限: 1000
# 反应: DCAtex, 下限: 0.0, 上限: 1000
# 反应: DCTPD, 下限: 0.0, 上限: 1000
# 反应: DCTPD2, 下限: 0.0, 上限: 1000
# 反应: DDCAtexi, 下限: 0.0, 上限: 1000
# 反应: DDGLK, 下限: 0.0, 上限: 1000
# 反应: DDPA, 下限: 0.0, 上限: 1000
# 反应: DESATPE160, 下限: 0.0, 上限: 1000
# 反应: DESATPG160, 下限: 0.0, 上限: 1000
# 反应: DGBUTNH, 下限: 0.0, 上限: 1000
# 反应: DGK1, 下限: -999999.0, 上限: 1000
# 反应: DM_C70aPHA_c, 下限: 0.0, 上限: 1000
# 反应: DM_C70pPHA_c, 下限: 0.0, 上限: 1000
# 反应: DM_C80aPHA_c, 下限: 0.0, 上限: 1000
# 反应: DM_C80pPHA_c, 下限: 0.0, 上限: 1000
# 反应: DM_C90aPHA_c, 下限: 0.0, 上限: 1000
# 反应: DM_C90pPHA_c, 下限: 0.0, 上限: 1000
# 反应: DM_acmum6p_c, 下限: 0.0, 上限: 1000
# 反应: DM_ppi50_c, 下限: 0.0, 上限: 1000
# 反应: DM_acgam_c, 下限: 0.0, 上限: 1000
# 反应: DM_doxopa_c, 下限: 0.0, 上限: 1000
# 反应: DM_tripeptide_c, 下限: 0.0, 上限: 1000
# 反应: DNMPPA, 下限: 0.0, 上限: 1000
# 反应: DNTAep, 下限: 0.0, 上限: 1000
# 反应: DNTPPA, 下限: 0.0, 上限: 1000
# 反应: DOPAtex, 下限: -999999.0, 上限: 1000
# 反应: DOPAtpp, 下限: -999999.0, 上限: 1000
# 反应: DOPDH, 下限: -999999.0, 上限: 1000
# 反应: DORNabcpp, 下限: 0.0, 上限: 1000
# 反应: DORNtex, 下限: -999999.0, 上限: 1000
# 反应: DPCOAK, 下限: 0.0, 上限: 1000
# 反应: DPHEt2rpp, 下限: -999999.0, 上限: 1000
# 反应: DPHEtex, 下限: -999999.0, 上限: 1000
# 反应: DPR, 下限: 0.0, 上限: 1000
# 反应: DPROabcpp, 下限: 0.0, 上限: 1000
# 反应: DPROtex, 下限: -999999.0, 上限: 1000
# 反应: DSBAO1, 下限: 0.0, 上限: 1000
# 反应: DSBCGT, 下限: 0.0, 上限: 1000
# 反应: DSBDR, 下限: 0.0, 上限: 1000
# 反应: DSBGGT, 下限: 0.0, 上限: 1000
# 反应: DSERt2pp, 下限: 0.0, 上限: 1000
# 反应: DSERtex, 下限: -999999.0, 上限: 1000
# 反应: DTMPK, 下限: -999999.0, 上限: 1000
# 反应: DTYRt2rpp, 下限: -999999.0, 上限: 1000
# 反应: DTYRtex, 下限: -999999.0, 上限: 1000
# 反应: DURAD, 下限: -999999.0, 上限: 1000
# 反应: DURAD2, 下限: -999999.0, 上限: 1000
# 反应: DUTPDP, 下限: 0.0, 上限: 1000
# 反应: DVALabcpp, 下限: 0.0, 上限: 1000
# 反应: DVALtex, 下限: -999999.0, 上限: 1000
# 反应: DXPRIi, 下限: 0.0, 上限: 1000
# 反应: DXPS, 下限: 0.0, 上限: 1000
# 反应: D_LACt2pp, 下限: -999999.0, 上限: 1000
# 反应: D_LACtex, 下限: -999999.0, 上限: 1000
# 反应: E4PD, 下限: -999999.0, 上限: 1000
# 反应: EAR100y, 下限: 0.0, 上限: 1000
# 反应: EAR120y, 下限: 0.0, 上限: 1000
# 反应: EAR121y, 下限: 0.0, 上限: 1000
# 反应: EAR140y, 下限: 0.0, 上限: 1000
# 反应: EAR141y, 下限: 0.0, 上限: 1000
# 反应: EAR160y, 下限: 0.0, 上限: 1000
# 反应: EAR161y, 下限: 0.0, 上限: 1000
# 反应: EAR180y, 下限: 0.0, 上限: 1000
# 反应: EAR181y, 下限: 0.0, 上限: 1000
# 反应: EAR40y, 下限: 0.0, 上限: 1000
# 反应: EAR60y, 下限: 0.0, 上限: 1000
# 反应: EAR80y, 下限: 0.0, 上限: 1000
# 反应: HBCE, 下限: -999999.0, 上限: 1000
# 反应: ECOAH1, 下限: -999999.0, 上限: 1000
# 反应: ECOAH12, 下限: 0.0, 上限: 1000
# 反应: ECOAH14, 下限: -999999.0, 上限: 1000
# 反应: ECOAH15, 下限: -999999.0, 上限: 1000
# 反应: ECOAH16, 下限: -999999.0, 上限: 1000
# 反应: ECOAH17, 下限: -999999.0, 上限: 1000
# 反应: ECOAH18, 下限: -999999.0, 上限: 1000
# 反应: ECOAH19, 下限: -999999.0, 上限: 1000
# 反应: ECOAH2, 下限: -999999.0, 上限: 1000
# 反应: EX_3oxoadp_e, 下限: 0.0, 上限: 1000
# 反应: EX_4abut_e, 下限: 0.0, 上限: 1000
# 反应: EX_4hbz_e, 下限: 0.0, 上限: 1000
# 反应: EX_4hpro_DC_e, 下限: 0.0, 上限: 1000
# 反应: EX_4hpro_LT_e, 下限: 0.0, 上限: 1000
# 反应: EX_5aptn_e, 下限: 0.0, 上限: 1000
# 反应: EX_5mcsn_e, 下限: 0.0, 上限: 1000
# 反应: EX_5oxpro_e, 下限: 0.0, 上限: 1000
# 反应: EX_6atha_e, 下限: 0.0, 上限: 1000
# 反应: EX_6hnac_e, 下限: 0.0, 上限: 1000
# 反应: EX_met__D_e, 下限: 0.0, 上限: 1000
# 反应: EX_LalaLglu_e, 下限: 0.0, 上限: 1000
# 反应: EX_Ncbmpts_e, 下限: 0.0, 上限: 1000
# 反应: EX_R3hdec4e_e, 下限: 0.0, 上限: 1000
# 反应: EX_R_3h4atba_e, 下限: 0.0, 上限: 1000
# 反应: EX_R_3h6atha_e, 下限: 0.0, 上限: 1000
# 反应: EX_R_3hcmrs7e_e, 下限: 0.0, 上限: 1000
# 反应: EX_R_3hdcaa_e, 下限: 0.0, 上限: 1000
# 反应: EX_R_3hdd5ea_e, 下限: 0.0, 上限: 1000
# 反应: EX_R_3hdd6e_e, 下限: 0.0, 上限: 1000
# 反应: EX_R_3hdda_e, 下限: 0.0, 上限: 1000
# 反应: EX_R_3hhdca_e, 下限: 0.0, 上限: 1000
# 反应: EX_R_3hhpa_e, 下限: 0.0, 上限: 1000
# 反应: EX_R_3hhxa_e, 下限: 0.0, 上限: 1000
# 反应: EX_R_3hnonaa_e, 下限: 0.0, 上限: 1000
# 反应: EX_R_3hocta_e, 下限: 0.0, 上限: 1000
# 反应: EX_R_3hpba_e, 下限: 0.0, 上限: 1000
# 反应: EX_R_3hpdeca_e, 下限: 0.0, 上限: 1000
# 反应: EX_R_3hphpa_e, 下限: 0.0, 上限: 1000
# 反应: EX_R_3hphxa_e, 下限: 0.0, 上限: 1000
# 反应: EX_R_3hpnona_e, 下限: 0.0, 上限: 1000
# 反应: EX_R_3hpocta_e, 下限: 0.0, 上限: 1000
# 反应: EX_R_3hppta_e, 下限: 0.0, 上限: 1000
# 反应: EX_R_3hpt_e, 下限: 0.0, 上限: 1000
# 反应: EX_R_3htd58e_e, 下限: 0.0, 上限: 1000
# 反应: EX_R_3htd5e_e, 下限: 0.0, 上限: 1000
# 反应: EX_R_3httdca_e, 下限: 0.0, 上限: 1000
# 反应: EX_T4hcinnm_e, 下限: 0.0, 上限: 1000
# 反应: EX_ac_e, 下限: 0.0, 上限: 1000
# 反应: EX_acac_e, 下限: 0.0, 上限: 1000
# 反应: EX_acald_e, 下限: 0.0, 上限: 1000
# 反应: EX_acon_C_e, 下限: 0.0, 上限: 1000
# 反应: EX_acser_e, 下限: 0.0, 上限: 1000
# 反应: EX_actn__R_e, 下限: 0.0, 上限: 1000
# 反应: EX_ade_e, 下限: 0.0, 上限: 1000
# 反应: EX_adn_e, 下限: 0.0, 上限: 1000
# 反应: EX_adocbl_e, 下限: 0.0, 上限: 1000
# 反应: EX_ag_e, 下限: 0.0, 上限: 1000
# 反应: EX_agm_e, 下限: 0.0, 上限: 1000
# 反应: EX_akg_e, 下限: 0.0, 上限: 1000
# 反应: EX_ala_B_e, 下限: 0.0, 上限: 1000
# 反应: EX_ala__D_e, 下限: 0.0, 上限: 1000
# 反应: EX_ala__L_e, 下限: 0.0, 上限: 1000
# 反应: EX_alaala_e, 下限: 0.0, 上限: 1000
# 反应: EX_alahis_e, 下限: 0.0, 上限: 1000
# 反应: EX_alaleu_e, 下限: 0.0, 上限: 1000
# 反应: EX_alathr_e, 下限: 0.0, 上限: 1000
# 反应: EX_alatrp_e, 下限: 0.0, 上限: 1000
# 反应: EX_algac_MG_14_e, 下限: 0.0, 上限: 1000
# 反应: EX_algac_MG_23_e, 下限: 0.0, 上限: 1000
# 反应: EX_algac_MG_32_e, 下限: 0.0, 上限: 1000
# 反应: EX_algac_MG_41_e, 下限: 0.0, 上限: 1000
# 反应: EX_algac__M_e, 下限: 0.0, 上限: 1000
# 反应: EX_alltn_e, 下限: 0.0, 上限: 1000
# 反应: EX_apc_e, 下限: 0.0, 上限: 1000
# 反应: EX_arbtn_e, 下限: 0.0, 上限: 1000
# 反应: EX_arbtn_fe3_e, 下限: 0.0, 上限: 1000
# 反应: EX_arg__D_e, 下限: 0.0, 上限: 1000
# 反应: EX_arg__L_e, 下限: 0.0, 上限: 1000
# 反应: EX_asn__D_e, 下限: 0.0, 上限: 1000
# 反应: EX_asn__L_e, 下限: 0.0, 上限: 1000
# 反应: EX_aso3_e, 下限: 0.0, 上限: 1000
# 反应: EX_aso4_e, 下限: 0.0, 上限: 1000
# 反应: EX_asp__L_e, 下限: 0.0, 上限: 1000
# 反应: EX_balaala_e, 下限: 0.0, 上限: 1000
# 反应: EX_balabala_e, 下限: 0.0, 上限: 1000
# 反应: EX_balagly_e, 下限: 0.0, 上限: 1000
# 反应: EX_balaleu_e, 下限: 0.0, 上限: 1000
# 反应: EX_balamd_e, 下限: 0.0, 上限: 1000
# 反应: EX_bhb_e, 下限: 0.0, 上限: 1000
# 反应: EX_biliverd_e, 下限: 0.0, 上限: 1000
# 反应: 3HAD161, 下限: 0.0, 上限: 1000
# 反应: 3HAD180, 下限: 0.0, 上限: 1000
# 反应: 3HAD181, 下限: 0.0, 上限: 1000
# 反应: 3HAD40, 下限: 0.0, 上限: 1000
# 反应: 3HAD60, 下限: 0.0, 上限: 1000
# 反应: 3HAD80, 下限: 0.0, 上限: 1000
# 反应: HBCHLR, 下限: -999999.0, 上限: 1000
# 反应: 3HBCOAHL, 下限: 0.0, 上限: 1000
# 反应: 3HLYTCL, 下限: 0.0, 上限: 1000
# 反应: 3MBZALDH, 下限: 0.0, 上限: 1000
# 反应: 3MBZDH, 下限: 0.0, 上限: 1000
# 反应: 3MBt2pp, 下限: 0.0, 上限: 1000
# 反应: 3MBtex, 下限: -999999.0, 上限: 1000
# 反应: 3MCAT23DOX, 下限: 0.0, 上限: 1000
# 反应: 3OADPCOAT, 下限: 0.0, 上限: 1000
# 反应: 3OAR100, 下限: -999999.0, 上限: 1000
# 反应: 3OAR120, 下限: -999999.0, 上限: 1000
# 反应: 3OAR121, 下限: 0.0, 上限: 1000
# 反应: 3OAR140, 下限: -999999.0, 上限: 1000
# 反应: 3OAR141, 下限: 0.0, 上限: 1000
# 反应: 3OAR160, 下限: -999999.0, 上限: 1000
# 反应: 3OAR161, 下限: 0.0, 上限: 1000
# 反应: 3OAR180, 下限: -999999.0, 上限: 1000
# 反应: 3OAR181, 下限: 0.0, 上限: 1000
# 反应: 3OAR40, 下限: -999999.0, 上限: 1000
# 反应: 3OAR60, 下限: -999999.0, 上限: 1000
# 反应: 3OAR80, 下限: -999999.0, 上限: 1000
# 反应: 3OAS100, 下限: 0.0, 上限: 1000
# 反应: 3OAS120, 下限: 0.0, 上限: 1000
# 反应: 3OAS121, 下限: 0.0, 上限: 1000
# 反应: 3OAS140, 下限: 0.0, 上限: 1000
# 反应: 3OAS141, 下限: 0.0, 上限: 1000
# 反应: 3OAS160, 下限: 0.0, 上限: 1000
# 反应: 3OAS161, 下限: 0.0, 上限: 1000
# 反应: 3OAS180, 下限: 0.0, 上限: 1000
# 反应: 3OAS181, 下限: 0.0, 上限: 1000
# 反应: 3OAS60, 下限: 0.0, 上限: 1000
# 反应: 3OAS80, 下限: 0.0, 上限: 1000
# 反应: 3OXCOAT, 下限: 0.0, 上限: 1000
# 反应: 3OXOADPt_ex, 下限: -999999.0, 上限: 1000
# 反应: 3OXOADPt_pp, 下限: -999999.0, 上限: 1000
# 反应: 3PQQS, 下限: -999999.0, 上限: 1000
# 反应: 3_4DHBZ1t_pp, 下限: -999999.0, 上限: 1000
# 反应: 3_4DHBZt2, 下限: -999999.0, 上限: 1000
# 反应: 4ABUTabcpp, 下限: 0.0, 上限: 1000
# 反应: 4CMCOAS, 下限: 0.0, 上限: 1000
# 反应: 4CMLCL_kt, 下限: 0.0, 上限: 1000
# 反应: 4HBADH, 下限: -999999.0, 上限: 1000
# 反应: 4HBHYOX, 下限: 0.0, 上限: 1000
# 反应: 4HBZtex, 下限: -999999.0, 上限: 1000
# 反应: 4HDPROO, 下限: 0.0, 上限: 1000
# 反应: 4HPRODCabcpp, 下限: 0.0, 上限: 1000
# 反应: 4HPRODCtex, 下限: -999999.0, 上限: 1000
# 反应: 4HPROE, 下限: -999999.0, 上限: 1000
# 反应: 4HPROLTabcpp, 下限: 0.0, 上限: 1000
# 反应: 4HPROLTtex, 下限: -999999.0, 上限: 1000
# 反应: 4HTHRS, 下限: 0.0, 上限: 1000
# 反应: 4MBZALDH, 下限: 0.0, 上限: 1000
# 反应: 4MBZDH, 下限: 0.0, 上限: 1000
# 反应: 4MCAT23DOX, 下限: 0.0, 上限: 1000
# 反应: 4OD, 下限: 0.0, 上限: 1000

# %%
# 定义新的代谢物（如果不存在则添加）
new_metabolites = []

if 'tpa_c' not in model.metabolites:
    tpa_c = Metabolite('tpa_c', formula='C8H4O4', name='Terephthalate', charge=-2, compartment='c')
    new_metabolites.append(tpa_c)

if 'tpa_e' not in model.metabolites:
    tpa_e = Metabolite('tpa_e', formula='C8H4O4', name='Terephthalate', charge=-2, compartment='e')
    new_metabolites.append(tpa_e)

if 'dhchdc_c' not in model.metabolites:
    dhchdc_c = Metabolite('dhchdc_c', formula='C8H6O6', name='(3S,4R)-3,4-Dihydroxycyclohexa-1,5-diene-1,4-dicarboxylate', charge=-2, compartment='c')
    new_metabolites.append(dhchdc_c)
#3,4-Dihydroxybenzoate==PCA

if '3h3h_c' not in model.metabolites:
    haa_c = Metabolite('3h3h_c', formula='C20H37O5', name='3-hydroxydecanoyl-3-hydroxydecanoate', charge=-1, compartment='c')
    new_metabolites.append(haa_c)
    
if '3h3h_e' not in model.metabolites:
    haa_e = Metabolite('3h3h_e', formula='C20H37O5', name='3-hydroxydecanoyl-3-hydroxydecanoate', charge=-1, compartment='e')
    new_metabolites.append(haa_e)

if 'lrhh_c' not in model.metabolites:
    lrhh_c = Metabolite('lrhh_c', formula='C26H47O9', name='L-rhamnosyl-3-hydroxydecanoyl-3-hydroxydecanoate', charge=-1, compartment='c')
    new_metabolites.append(lrhh_c)

if 'lrhh_e' not in model.metabolites:
    lrhh_e = Metabolite('lrhh_e', formula='C26H47O9', name='L-rhamnosyl-3-hydroxydecanoyl-3-hydroxydecanoate', charge=-1, compartment='e')
    new_metabolites.append(lrhh_e)
# 将新的代谢物添加到模型中
model.add_metabolites(new_metabolites)

# %%
o2_c = model.metabolites.get_by_id('o2_c')
nad_c = model.metabolites.get_by_id('nad_c')
nadh_c = model.metabolites.get_by_id('nadh_c')
nadp_c = model.metabolites.get_by_id('nadp_c')
nadph_c = model.metabolites.get_by_id('nadph_c')
h_c = model.metabolites.get_by_id('h_c')
h2o_c = model.metabolites.get_by_id('h2o_c')
dhchdc_c = model.metabolites.get_by_id('dhchdc_c')  
co2_c = model.metabolites.get_by_id('co2_c') 
dhbz_c = model.metabolites.get_by_id('34dhbz_c')
hydroxydecanoyl_acp = model.metabolites.get_by_id('3hdecACP_c')#C21H39N2O9PRS电荷：-1
hydroxydecanoyl_hydroxydecanoate = model.metabolites.get_by_id('3h3h_c')
haa = model.metabolites.get_by_id('3h3h_e')
ACP_c = model.metabolites.get_by_id('ACP_c')
dtdprmn_c = model.metabolites.get_by_id('dtdprmn_c')
dtdp_c = model.metabolites.get_by_id('dtdp_c')
lrhh_c = model.metabolites.get_by_id('lrhh_c')
lrhh_e = model.metabolites.get_by_id('lrhh_e')

# %%
# 定义 TPA 的交换反应
tpa_exchange_reaction = Reaction('EX_tpa_e')
tpa_exchange_reaction.name = 'Terephthalic acid exchange'
tpa_exchange_reaction.lower_bound = 0  
tpa_exchange_reaction.upper_bound = 1000   
tpa_exchange_reaction.add_metabolites({
    tpa_e: -1  # 环境中的 TPA
})


# TPA转运反应 (tpaK)
tpa_transport = Reaction('TPA_transport')
tpa_transport.name = 'TPA_transport'
tpa_transport.lower_bound = 0  
tpa_transport.upper_bound = 1000
tpa_transport.add_metabolites({
    tpa_e: -1,
    tpa_c: 1  # Assuming tpa_e is the extracellular TPA
})

# TPA双加氧酶反应 (tphA123)
tphA123 = Reaction('TPHA123')
tphA123.name = 'TPA Dioxygenase Reaction'
tphA123.lower_bound = -1000  # 可逆反应
tphA123.upper_bound = 1000
tphA123.add_metabolites({
    tpa_c: -1,
    o2_c: -1,
    nadph_c: -1,
    h_c: -1,
    dhchdc_c: 1,
    nadp_c: 1
})

# 二醇脱氢酶反应 (tphB)
tphB = Reaction('TPHB')
tphB.name = 'Diol Dehydrogenase Reaction'
tphB.lower_bound = -1000
tphB.upper_bound = 1000
tphB.add_metabolites({
    dhchdc_c: -1,  # (3S,4R)-3,4-Dihydroxycyclohexa-1,5-diene-1,4-dicarboxylate
    nadp_c: -1,                                 
    dhbz_c: 1,                      # 3,4-Dihydroxybenzoate
    co2_c: 1,                                  
    nadph_c: 1,                                   
})

# HAA合成 (rhlA)
rhlA = Reaction('RHLA')
rhlA.name = 'Rhamnosyltransferase chain A'
rhlA.lower_bound = 0
rhlA.upper_bound = 999999
rhlA.add_metabolites({
     hydroxydecanoyl_acp: -2,  # 消耗 2 个 3hdeACP_c
    h2o_c: -1,                # 消耗 1 个 H2O
    hydroxydecanoyl_hydroxydecanoate: 1,  # 生成 1 个 3h3h_c (HAA)
    h_c: 1,
    ACP_c: 2              # 生成 2 个 ACP_c
})

# 单鼠李糖脂合成 (rhlB)
rhlB = Reaction('RHLB')
rhlB.name = 'Rhamnosyltransferase chain B'
rhlB.lower_bound = 0
rhlB.upper_bound = 999999
rhlB.add_metabolites({
    hydroxydecanoyl_hydroxydecanoate: -1,  # 消耗 1 个 3h3h_c (HAA)
    dtdprmn_c: -1,                           # 消耗 1 个 dtdprmn_c
    #h_c: -1,                            # 消耗 1 个 h_c
    dtdp_c: 1,                               # 生成 1 个 dtdp_c
    h_c: 1,
    lrhh_c: 1                                # 生成 1 个 lrhh_c
})

# 定义 lrhh 的交换反应
lrhh_exchange_reaction = Reaction('EX_lrhh_e')
lrhh_exchange_reaction.name = 'lrhh exchange'
lrhh_exchange_reaction.lower_bound = 0  
lrhh_exchange_reaction.upper_bound = 1000   
lrhh_exchange_reaction.add_metabolites({
    lrhh_e: 1  
})


# lrhh转运反应 
lrhh_transport = Reaction('lrhh_transport')
lrhh_transport.name = 'lrhh_transport'
lrhh_transport.lower_bound = 0  
lrhh_transport.upper_bound = 1000
lrhh_transport.add_metabolites({
    lrhh_c: -1,
    lrhh_e: 1 
})
# PHA降解 (phaZ)
#phaZ = Reaction('PHAZ')
#phaZ.name = 'PHA Degradation'
#phaZ.lower_bound = 0
#phaZ.upper_bound = 1000
#phaZ.add_metabolites({
#    'pha_c': -1,
#    'products_c': 1  # Replace 'products_c' with the correct degradation products
#})

# 将新的反应添加到模型中
model.add_boundary(tpa_e, type = 'exchange')
model.add_boundary(lrhh_e, type = 'exchange')
model.add_reactions([tpa_transport, tphA123, tphB, rhlA, rhlB, lrhh_transport])

# %%
for reaction in [haa_exchange_reaction, haa_transport]:
    print(f"反应ID: {reaction.id}")
    print(f"反应名称: {reaction.name}")
    print(f"反应方程: {reaction.reaction}")
    print(f"下限: {reaction.lower_bound}")
    print(f"上限: {reaction.upper_bound}")
    print("\n")
# Out:
# 反应ID: EX_haa_e
# 反应名称: Haa exchange
# 反应方程: 3h3h_e -->
# 下限: 0
# 上限: 999999
#
#
# 反应ID:
# 反应名称: HAA_transport
# 反应方程: 3h3h_e --> 3h3h_c
# 下限: 0
# 上限: 999999

# %%
for reaction in [tpa_exchange_reaction, tpa_transport, tphA123, tphB, rhlA, rhlB, lrhh_transport, lrhh_exchange_reaction ]:
    print(f"反应ID: {reaction.id}")
    print(f"反应名称: {reaction.name}")
    print(f"反应方程: {reaction.reaction}")
    print(f"下限: {reaction.lower_bound}")
    print(f"上限: {reaction.upper_bound}")
    print("\n")
# Out:
# 反应ID: EX_tpa_e
# 反应名称: Terephthalic acid exchange
# 反应方程: tpa_e -->
# 下限: 0
# 上限: 1000
#
#
# 反应ID: TPA_transport
# 反应名称: TPA_transport
# 反应方程: tpa_e --> tpa_c
# 下限: 0
# 上限: 1000
#
#
# 反应ID: TPHA123
# 反应名称: TPA Dioxygenase Reaction
# 反应方程: h_c + nadph_c + o2_c + tpa_c <=> dhchdc_c + nadp_c
# 下限: -1000
# 上限: 1000
#
#
# 反应ID: TPHB
# 反应名称: Diol Dehydrogenase Reaction
# 反应方程: dhchdc_c + nadp_c <=> 34dhbz_c + co2_c + nadph_c
# 下限: -1000
# 上限: 1000
#
#
# 反应ID: RHLA
# 反应名称: Rhamnosyltransferase chain A
# 反应方程: 2 3hdecACP_c + h2o_c --> 3h3h_c + 2 ACP_c + h_c
# 下限: 0
# 上限: 999999
#
#
# 反应ID: RHLB
# 反应名称: Rhamnosyltransferase chain B
# 反应方程: 3h3h_c + dtdprmn_c --> dtdp_c + h_c + lrhh_c
# 下限: 0
# 上限: 999999
#
#
# 反应ID: lrhh_transport
# 反应名称: lrhh_transport
# 反应方程: lrhh_c --> lrhh_e
# 下限: 0
# 上限: 1000
#
#
# 反应ID: EX_lrhh_e
# 反应名称: lrhh exchange
# 反应方程:  --> lrhh_e
# 下限: 0
# 上限: 1000

# %%
for reaction in [tpa_transport, tphA123, tphB, rhlA, rhlB]:
    print(reaction.check_mass_balance())
# Out:
# {}
# {}
# {}
# {}
# {}

# %%
# 保存修改后的模型
cobra.io.write_sbml_model(model, 'modified_iJN1463.xml')
